# %% [markdown]
# # Topic modeling hexameter corpus

# %%
import sys;sys.path.append('..')
from ppanlp import *
ppa = PPA()

# %%
url_hexameter_texts = 'https://docs.google.com/spreadsheets/d/e/' \
'2PACX-1vSMEiSg0lWf_r2HrNQtKHSe76Sbk-DSpb_93FDwSOmlP5sjwwsreWOXJWPJ6ruzJQ/pub?gid=906568184&single=true&output=csv'

# %%
from intspan import intspan

# %%
df_texts=pd.read_csv(url_hexameter_texts)
df_texts.columns = ['title', 'work_id', 'pages_orig', 'pages_digital','author']
df_texts['pages_digital']=df_texts['pages_digital'].apply(lambda x: '' if not x.strip()[0].isdigit() else x.strip())
df_texts
# Out:
#                                                 title  \
# 0            Lectures on Rhetoric and Belles Lettres
# 1   The poetical Decameron, or, Ten conversations ...
# 2       ‘Review of Preface to A Vision of Judgement’
# 3   Historical and critical remarks upon the moder...
# 4   The Principles of Rhythm, both in Speech and M...
# 5   The history of English poetry, from the close ...
# 6   Prosodia graeca, or, An exposition of the Gree...
# 7   The beauties of modern literature, in verse an...
# 8   A general critical grammar of the Inglish lang...
# 9                   The philosophy of the human voice
# 10                A treatise on English versification
# 11  A key to the classical pronunciation of Greek,...
# 12  Poetical works. To which have been prefixed th...
# 13             An abridgment of Elements of criticism
# 14              The principles of English composition
# 15                                    English grammar
# 16                                        Prose works
# 17                               Biographia literaria
# 18                 A history of English rhythms, v. 1
# 19                 A history of English rhythms, v. 2
# 20                 Lectures on rhetoric and criticism
# 21                  Critical and miscellaneous essays
# 22                              Elements of criticism
# 23  Introduction to the literature of Europe in th...
# 24  Garrick's mode of reading the liturgy of the C...
# 25     Review of Longfellow's Ballads and Other Poems
# 26                           The psalmists of Britain
# 27  Sketches of the history of literature and lear...
# 28                    A system of Latin versification
# 29  The Practice of Writing English in Classical M...
# 30        The principles of Latin and English grammar
# 31          Short Chapters on Novel and Exotic Metres
# 32          Short Chapters on Novel and Exotic Metres
# 33                     Dialogue on English Hexameters
#
#                      work_id    pages_orig pages_digital  \
# 0                 hvd.hxjgck       79-106         87-113
# 1         nyp.33433074834932        77-145       131-199
# 2    njp.32101076378536-p436        422-36       436-450
# 3                 hvd.hnjimv   Whole text.
# 4         nyp.33433056659844       126-163       158-195
# 5                 hvd.hwdqtx        47-450       565-968
# 6         hvd.32044081367153   Whole text.
# 7         nyp.33433076078660       299-313      409- 423
# 8            nnc1.cu58512900       225-247       261-283
# 9         nyp.33433084113012       149-179       165-195
# 10        njp.32101072898289        77-112        93-128
# 11        hvd.32044038398848       251-285       285-319
# 12   hvd.32044086791217-p127         15-20       127-132
# 13        nyp.33433082502950       133-160      141- 169
# 14                hvd.hn1lrz       177-191       189-203
# 15           nnc1.0023835788       445-455       459-469
# 16                hvd.hwad76        80-101        96-117
# 17        mdp.39015004729847       308-320       310-322
# 18        nyp.33433069243206       105-184       125-204
# 19        nyp.33433069243198       234-264       254-283
# 20           nnc1.cu58485317       294-421       304-433
# 21                hvd.hn641h       243-341       263-363
# 22                hvd.ah69fe       289-325       293-329
# 23        nyp.33433082497631       155-213       183-241
# 24        hvd.32044088290994       1 to 60         25-84
# 25   hvd.32044009957044-p140   Whole text.
# 26       yale.39002004911344       224-228       260-264
# 27              uc1.$b287385       160-166       422-428
# 28                hvd.hn1s5z   Whole text.
# 29   njp.32101073025528-p299   Whole text.
# 30        nyp.33433082313754       272-290       294-312
# 31   hvd.32044031571342-p100  Whole text.
# 32   hvd.32044054989868-p536  Whole text.
# 33  umn.31951000742933f-p673  Whole text.
#
#                       author
# 0                Blair, Hugh
# 1        Collier, John Payne
# 2                       Anon
# 3          Tillbrook, Samuel
# 4               Roe, Richard
# 5             Warton, Thomas
# 6             Dunbar, George
# 7          MacDermot, Martin
# 8             Oliver, Samuel
# 9                Rush, James
# 10            Crowe, William
# 11              Walker, John
# 12             Sayers, Frank
# 13   Kames, Henry Home, Lord
# 14              Booth, David
# 15         Priestley, Joseph
# 16        Scott, Walter, Sir
# 17  Coleridge, Samuel Taylor
# 18              Guest, Edwin
# 19              Guest, Edwin
# 20        MacGill, Stevenson
# 21           Carlyle, Thomas
# 22   Kames, Henry Home, Lord
# 23             Hallam, Henry
# 24             Cull, Richard
# 25                      Anon
# 26             Holland, John
# 27          Craik, George L.
# 28           Anthon, Charles
# 29            Oxenford, John
# 30           Adam, Alexander
# 31              Benson, Carl
# 32              Benson, Carl
# 33                Whewell, W

# %%
def iter_pages(self, df):
    id2pages = {
        id:set(intspan(prange)) if prange else prange
        for id,prange in zip(df.work_id, df.pages_digital)
    }
    for page in self.iter_pages():
        if not page.text.id in id2pages: continue
        pagerange = id2pages[page.text.id]
        pagenum = page.meta['page_num']
        if not pagerange or pagenum in pagerange:
            yield page

# %%
pages = list(iter_pages(ppa,df_texts))
# Out:
# 2023-12-08 08:02:32,027 | iterating pages by corpus jsonl file
# Iterating over pages.jsonl.gz: 100%|█████████████████████████████████████████████████████████| 2160441/2160441 [00:22<00:00, 94996.22it/s]
# 2023-12-08 08:02:54,773 | 22.75 seconds

# %%
len(pages)
# Out:
# 2038

# %%
def topic_model(pages, ntopics=25, niter=100):
    mdl = tp.LDAModel(k=ntopics)
    docd={}
    for page in pages:
        docd[page.id] = mdl.add_doc(page.content_words)
    def getdesc():
        return f'Training model (ndocs={len(docd)}, log-likelihood = {mdl.ll_per_word:.4})'
    
    pbar=tqdm(list(range(0, niter, 1)),desc=getdesc(),position=0)
    for i in pbar:
        pbar.set_description(getdesc())
        mdl.train(1)
    return mdl,docd

# %%
mdl,docd = topic_model(pages)
# Out:
# Training model (ndocs=2038, log-likelihood = -10.03): 100%|█████████████████████████████████████████████| 100/100 [00:01<00:00, 60.05it/s]

# %%
mdl.summary(topic_word_top_n=10)
# Out:
# <Basic Info>
# | LDAModel (current version: 0.12.5)
# | 1987 docs, 321827 words
# | Total Vocabs: 64104, Used Vocabs: 64104
# | Entropy of words: 9.40720
# | Entropy of term-weighted words: 9.40720
# | Removed Vocabs: <NA>
# |
# <Training Info>
# | Iterations: 100, Burn-in steps: 0
# | Optimization Interval: 10
# | Log-likelihood per word: -10.03290
# |
# <Initial Parameters>
# | tw: TermWeight.ONE
# | min_cf: 0 (minimum collection frequency of words)
# | min_df: 0 (minimum document frequency of words)
# | rm_top: 0 (the number of top words to be removed)
# | k: 25 (the number of topics between 1 ~ 32767)
# | alpha: [0.1] (hyperparameter of Dirichlet distribution for document-topic, given as a single `float` in case of symmetric prior and as a list with length `k` of `float` in case of asymmetric prior.)
# | eta: 0.01 (hyperparameter of Dirichlet distribution for topic-word)
# | seed: 2741382038 (random seed)
# | trained in version 0.12.5
# |
# <Parameters>
# | alpha (Dirichlet prior on the per-document topic distributions)
# |  [0.08311606 0.16555345 0.01733496 0.05471245 0.30767852 0.2092899
# |   0.07760351 0.13306497 0.29117027 0.04188171 0.06581778 0.14833896
# |   0.29372457 0.42525163 0.12124106 0.5154785  0.14754726 0.22123952
# |   0.1551058  0.17063218 0.15622023 0.09303352 0.09510908 0.07626224
# |   0.17731065]
# | eta (Dirichlet prior on the per-topic word distribution)
# |  0.01
# |
# <Topics>
# | #0 (7892) : ille part quid quam suus nunc quis ipse ante nomen
# | #1 (11305) : thou shall thee lord eyes hath hand death unto sweet
# | #2 (4458) : versification sich latin part nicht hexameters doch pentameters stage nūnc
# | #3 (8961) : hire thei upon thus grete hath history thou good hadde
# | #4 (20340) : much first poetry perhaps many literature could last rather spirit
# | #5 (17476) : even world must time life whole johnson true without good
# | #6 (5232) : like white fair venus bright plus pour mars noble full
# | #7 (7333) : house said made city every took shall church fame might
# | #8 (21953) : verse syllables line word short pause english long syllable words
# | #9 (9129) : eurip prosodia ante graeca vide soph apud etiam aristoph compositis
# | #10 (6402) : henry full thai gold ther thus king gret boke saint
# | #11 (10066) : among mentioned edit many wrote history chaucer author part tales
# | #12 (18490) : manner knowledge every mind character thus object nature also writing
# | #13 (25754) : would though upon english much well poet might poetry modern
# | #14 (10483) : latin poem french italian romance poetry paris century history subject
# | #15 (33955) : must language time subject words great sometimes different expression would
# | #16 (17125) : year printed english also french written king called translated first
# | #17 (16043) : like still ever life german things hope long little among
# | #18 (7820) : part whose lord great death another next name well days
# | #19 (14082) : long quantity syllable short accent greek vowel thus latin first
# | #20 (9230) : english poems metre poets verses lines metres rhythm hexameter latin
# | #21 (6205) : spenser queen called court knights castle bishop poem many ladies
# | #22 (11026) : latin versification next verse part plural things forth mind paraphrase
# | #23 (9045) : verse second fourth third first spondee line foot feet bourne
# | #24 (12022) : king light away night many nibelungen love last first battle
# |

# %%
import pyLDAvis
topic_term_dists = np.stack([mdl.get_topic_word_dist(k) for k in range(mdl.k)])
doc_topic_dists = np.stack([doc.get_topic_dist() for doc in mdl.docs])
doc_topic_dists /= doc_topic_dists.sum(axis=1, keepdims=True)
doc_lengths = np.array([len(doc.words) for doc in mdl.docs])
vocab = list(mdl.used_vocabs)
term_frequency = mdl.used_vocab_freq

prepared_data = pyLDAvis.prepare(
    topic_term_dists, 
    doc_topic_dists, 
    doc_lengths, 
    vocab, 
    term_frequency,
    start_index=0, # tomotopy starts topic ids with 0, pyLDAvis with 1
    sort_topics=False # IMPORTANT: otherwise the topic_ids between pyLDAvis and tomotopy are not matching!
)

pyLDAvis.save_html(prepared_data, 'ldavis.html')
# Out:
# /Users/ryanheuser/github/ppa-nlp/venv/lib/python3.10/site-packages/pandas/core/dtypes/cast.py:1641: DeprecationWarning: np.find_common_type is deprecated.  Please use `np.result_type` or `np.promote_types`.
# See https://numpy.org/devdocs/release/1.25.0-notes.html and the docs for more information.  (Deprecated NumPy 1.25)
#   return np.find_common_type(types, [])

# %%
# !open ./ldavis.html
