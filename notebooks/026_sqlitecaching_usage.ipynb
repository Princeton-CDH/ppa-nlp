# %%
import sys;sys.path.append('..')
from ppanlp.corpus import *
from ppanlp.imports import *

# %%
ppa = PPA()
ppa.nlp
# Out:
# 2023-12-04 14:12:06 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# ...
# 2023-12-04 14:12:06 WARNING: Language en package default expects mwt, which has been added
# 2023-12-04 14:12:07 INFO: Loading these models for language: en (English):
# ...
# | Processor | Package                   |
# -----------------------------------------
# | tokenize  | combined                  |
# | mwt       | combined                  |
# | ner       | ontonotes-ww-multi_charlm |
# ...
#
# 2023-12-04 14:12:07 INFO: Using device: cpu
# 2023-12-04 14:12:07 INFO: Loading: tokenize
# 2023-12-04 14:12:08 INFO: Loading: mwt
# 2023-12-04 14:12:08 INFO: Loading: ner
# 2023-12-04 14:12:09 INFO: Done loading processors!

# %%
ppa.ner_parse(max_per_cluster=25,min_doc_len=25)
# Out:
# ents_db...
# frac_None.25=25.work_ids_None <peewee.Expression object at 0x142563550>

# %%
t=ppa.textd['hvd.hn5wzt']
t.id
# Out:
# 'hvd.hn5wzt'

# %%
t.pages
