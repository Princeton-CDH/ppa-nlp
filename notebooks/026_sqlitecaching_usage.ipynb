# %%
import sys;sys.path.append('..')
from ppanlp.corpus import *
from ppanlp.imports import *

# %%
ppa = PPA('~/ppa_data/corpus2')

# %%
# %%timeit
for t in ppa:
    t.gen(force=True)
# Out:
# Iteration over texts in PPA:  78%|███████▊  | 5380/6939 [38:43<06:57,  3.74it/s]

# %%
t.pages

# %%
ppa.page_db.count_documents({'page_num_content_words':{'$gte':25}, '_random':{'$lte':0.25}})
# Out:
# 8341

# %%
# %%timeit
for t in piter(texts): 
    t.pages
    if 'pages' in t.__dict__: del t.__dict__['pages']
# Out:
# 2.52 s ± 28.9 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
for t in piter(texts): 
    t.pages_json_preproc
    if 'pages_json_preproc' in t.__dict__: del t.__dict__['pages_json_preproc']
# Out:
# 2.18 s ± 8.05 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# Out:
# 0

# %%
# %%timeit
t=ppa.text
t.gen()
t.pages
# Out:
# found 422 pages
# found 550 pages
# found 290 pages
# found 428 pages
# found 462 pages
# found 308 pages
# found 396 pages
# found 408 pages
# found 80 pages
# found 138 pages
# found 2 pages
# found 420 pages
# found 348 pages
# found 402 pages
# found 342 pages
# found 472 pages
# found 36 pages
# found 540 pages
# found 9 pages
# found 194 pages
# found 448 pages
# found 400 pages
# found 204 pages
# found 252 pages
# found 360 pages
# found 410 pages
# found 30 pages
# found 202 pages
# found 274 pages
# found 328 pages
# found 504 pages
# found 182 pages
# found 310 pages
# found 416 pages
# found 94 pages
# found 470 pages
# found 138 pages
# found 114 pages
# found 358 pages
# found 136 pages
# found 154 pages
# found 456 pages
# found 428 pages
# found 194 pages
# found 236 pages
# found 256 pages
# found 64 pages
# found 254 pages
# found 202 pages
# found 252 pages
# found 364 pages
# found 18 pages
# found 17 pages
# found 724 pages
# found 4 pages
# found 522 pages
# ...

# %%
# %%timeit
t=ppa.text
t.pages_json_preproc
# Out:
# 17 ms ± 2.37 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
