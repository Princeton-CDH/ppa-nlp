# %%
import sys;sys.path.append('..')
from ppanlp.corpus import *
from ppanlp.cleanup import *
import multiprocessing as mp
mp.set_start_method('fork')

# %%
ppa = PPA('~/ppa_data/solrcorpus5')

# %%
ppa.texts
# Out:
# Iteration over texts in PPA: 100%|██████████| 6939/6939 [00:00<00:00, 429475.64it/s]
# [<ppanlp.corpus.PPAText at 0x13ffb3da0>,
#  <ppanlp.corpus.PPAText at 0x13ffb3710>,
#  <ppanlp.corpus.PPAText at 0x13ffb38c0>,
#  <ppanlp.corpus.PPAText at 0x13ffb3650>,
#  <ppanlp.corpus.PPAText at 0x13ffb35f0>,
#  <ppanlp.corpus.PPAText at 0x13ffb33b0>,
#  <ppanlp.corpus.PPAText at 0x13ffb36e0>,
#  <ppanlp.corpus.PPAText at 0x13ffb3500>,
#  <ppanlp.corpus.PPAText at 0x13ffb34a0>,
#  <ppanlp.corpus.PPAText at 0x13ffb3440>,
#  <ppanlp.corpus.PPAText at 0x13ffb3530>,
#  <ppanlp.corpus.PPAText at 0x13ffb3e90>,
#  <ppanlp.corpus.PPAText at 0x13ffb3e30>,
#  <ppanlp.corpus.PPAText at 0x13ffb3ec0>,
#  <ppanlp.corpus.PPAText at 0x13ffb3080>,
#  <ppanlp.corpus.PPAText at 0x13ffb3380>,
#  <ppanlp.corpus.PPAText at 0x13ffb30b0>,
#  <ppanlp.corpus.PPAText at 0x13ffb31a0>,
#  <ppanlp.corpus.PPAText at 0x13ffb3140>,
#  <ppanlp.corpus.PPAText at 0x13ffb31d0>,
#  <ppanlp.corpus.PPAText at 0x13ffb2f60>,
#  <ppanlp.corpus.PPAText at 0x13ffb2f00>,
#  <ppanlp.corpus.PPAText at 0x13ffb2fc0>,
#  <ppanlp.corpus.PPAText at 0x13ffb2d50>,
#  <ppanlp.corpus.PPAText at 0x13ffb3050>,
#  <ppanlp.corpus.PPAText at 0x13ffb2e70>,
#  <ppanlp.corpus.PPAText at 0x13ffb2ea0>,
#  <ppanlp.corpus.PPAText at 0x13ffb2bd0>,
#  <ppanlp.corpus.PPAText at 0x13ffb29f0>,
#  <ppanlp.corpus.PPAText at 0x13ffb2a20>,
#  <ppanlp.corpus.PPAText at 0x13ffb2ae0>,
#  <ppanlp.corpus.PPAText at 0x13ffb2840>,
#  <ppanlp.corpus.PPAText at 0x13ffb2870>,
#  <ppanlp.corpus.PPAText at 0x13ffb27e0>,
#  <ppanlp.corpus.PPAText at 0x13ffb2630>,
#  <ppanlp.corpus.PPAText at 0x13ffb2690>,
#  <ppanlp.corpus.PPAText at 0x13ffb23f0>,
#  <ppanlp.corpus.PPAText at 0x13ffb24b0>,
#  <ppanlp.corpus.PPAText at 0x13ffb2060>,
#  <ppanlp.corpus.PPAText at 0x13ffb2090>,
#  <ppanlp.corpus.PPAText at 0x13ffb2510>,
#  <ppanlp.corpus.PPAText at 0x13ffb2540>,
#  <ppanlp.corpus.PPAText at 0x13ffb2270>,
#  <ppanlp.corpus.PPAText at 0x13ffb26f0>,
#  <ppanlp.corpus.PPAText at 0x13ffb37d0>,
#  <ppanlp.corpus.PPAText at 0x13ffb3860>,
#  <ppanlp.corpus.PPAText at 0x13ffb3230>,
#  <ppanlp.corpus.PPAText at 0x13eb9c7d0>,
#  <ppanlp.corpus.PPAText at 0x13ffc04a0>,
#  <ppanlp.corpus.PPAText at 0x13ffc0440>,
#  <ppanlp.corpus.PPAText at 0x13ffc0260>,
#  <ppanlp.corpus.PPAText at 0x13ffc01d0>,
#  <ppanlp.corpus.PPAText at 0x13ffc0290>,
#  <ppanlp.corpus.PPAText at 0x13ffc03e0>,
#  <ppanlp.corpus.PPAText at 0x13ffc03b0>,
#  <ppanlp.corpus.PPAText at 0x13ffc0350>,
#  <ppanlp.corpus.PPAText at 0x13ffc02c0>,
#  <ppanlp.corpus.PPAText at 0x13ffc06b0>,
#  <ppanlp.corpus.PPAText at 0x13ffc0620>,
#  <ppanlp.corpus.PPAText at 0x13ffc0590>,
#  <ppanlp.corpus.PPAText at 0x13ffc0860>,
#  <ppanlp.corpus.PPAText at 0x13ffc07a0>,
#  <ppanlp.corpus.PPAText at 0x13ffc0710>,
#  <ppanlp.corpus.PPAText at 0x13ffc09e0>,
#  <ppanlp.corpus.PPAText at 0x13ffc0950>,
#  <ppanlp.corpus.PPAText at 0x13ffc08c0>,
#  <ppanlp.corpus.PPAText at 0x13ffc0bc0>,
#  <ppanlp.corpus.PPAText at 0x13ffc0b00>,
#  <ppanlp.corpus.PPAText at 0x13ffc0a70>,
#  <ppanlp.corpus.PPAText at 0x13ffc0d40>,
#  <ppanlp.corpus.PPAText at 0x13ffc0cb0>,
#  <ppanlp.corpus.PPAText at 0x13ffc0c20>,
#  <ppanlp.corpus.PPAText at 0x13ffc0ec0>,
#  <ppanlp.corpus.PPAText at 0x13ffc0e30>,
#  <ppanlp.corpus.PPAText at 0x13ffc0da0>,
#  <ppanlp.corpus.PPAText at 0x13ffc1070>,
#  <ppanlp.corpus.PPAText at 0x13ffc0fb0>,
#  <ppanlp.corpus.PPAText at 0x13ffc0f20>,
#  <ppanlp.corpus.PPAText at 0x13ffc11f0>,
#  <ppanlp.corpus.PPAText at 0x13ffc1160>,
#  <ppanlp.corpus.PPAText at 0x13ffc10d0>,
#  <ppanlp.corpus.PPAText at 0x13ffc13a0>,
#  <ppanlp.corpus.PPAText at 0x13ffc12e0>,
#  <ppanlp.corpus.PPAText at 0x13ffc1250>,
#  <ppanlp.corpus.PPAText at 0x13ffc1550>,
#  <ppanlp.corpus.PPAText at 0x13ffc14c0>,
#  <ppanlp.corpus.PPAText at 0x13ffc1430>,
#  <ppanlp.corpus.PPAText at 0x13ffc16d0>,
#  <ppanlp.corpus.PPAText at 0x13ffc1640>,
#  <ppanlp.corpus.PPAText at 0x13ffc15b0>,
#  <ppanlp.corpus.PPAText at 0x13ffc1850>,
#  <ppanlp.corpus.PPAText at 0x13ffc1760>,
#  <ppanlp.corpus.PPAText at 0x13ffc1a00>,
#  <ppanlp.corpus.PPAText at 0x13ffc1970>,
#  <ppanlp.corpus.PPAText at 0x13ffc18e0>,
#  <ppanlp.corpus.PPAText at 0x13ffc1bb0>,
#  <ppanlp.corpus.PPAText at 0x13ffc1b20>,
#  <ppanlp.corpus.PPAText at 0x13ffc1a60>,
#  <ppanlp.corpus.PPAText at 0x13ffc1d90>,
#  <ppanlp.corpus.PPAText at 0x13ffc1cd0>,
#  <ppanlp.corpus.PPAText at 0x13ffc1c10>,
#  <ppanlp.corpus.PPAText at 0x13ffc1fd0>,
#  <ppanlp.corpus.PPAText at 0x13ffc1f10>,
#  <ppanlp.corpus.PPAText at 0x13ffc1df0>,
#  <ppanlp.corpus.PPAText at 0x13ffc2180>,
#  <ppanlp.corpus.PPAText at 0x13ffc20f0>,
#  <ppanlp.corpus.PPAText at 0x13ffc2030>,
#  <ppanlp.corpus.PPAText at 0x13ffc2330>,
#  <ppanlp.corpus.PPAText at 0x13ffc22a0>,
#  <ppanlp.corpus.PPAText at 0x13ffc21e0>,
#  <ppanlp.corpus.PPAText at 0x13ffc24e0>,
#  <ppanlp.corpus.PPAText at 0x13ffc2450>,
#  <ppanlp.corpus.PPAText at 0x13ffc2390>,
#  <ppanlp.corpus.PPAText at 0x13ffc2690>,
#  <ppanlp.corpus.PPAText at 0x13ffc2600>,
#  <ppanlp.corpus.PPAText at 0x13ffc2540>,
#  <ppanlp.corpus.PPAText at 0x13ffc2840>,
#  <ppanlp.corpus.PPAText at 0x13ffc27b0>,
#  <ppanlp.corpus.PPAText at 0x13ffc26f0>,
#  <ppanlp.corpus.PPAText at 0x13ffc29f0>,
#  <ppanlp.corpus.PPAText at 0x13ffc2960>,
#  <ppanlp.corpus.PPAText at 0x13ffc28a0>,
#  <ppanlp.corpus.PPAText at 0x13ffc2b70>,
#  <ppanlp.corpus.PPAText at 0x13ffc2ae0>,
#  <ppanlp.corpus.PPAText at 0x13ffc2a50>,
#  <ppanlp.corpus.PPAText at 0x13ffc2d20>,
#  <ppanlp.corpus.PPAText at 0x13ffc2c90>,
#  <ppanlp.corpus.PPAText at 0x13ffc2bd0>,
#  <ppanlp.corpus.PPAText at 0x13ffc2ea0>,
#  <ppanlp.corpus.PPAText at 0x13ffc2e10>,
#  <ppanlp.corpus.PPAText at 0x13ffc2d80>,
#  <ppanlp.corpus.PPAText at 0x13ffc3020>,
#  <ppanlp.corpus.PPAText at 0x13ffc2f90>,
#  <ppanlp.corpus.PPAText at 0x13ffc2f00>,
#  <ppanlp.corpus.PPAText at 0x13ffc31a0>,
#  <ppanlp.corpus.PPAText at 0x13ffc3110>,
#  <ppanlp.corpus.PPAText at 0x13ffc3080>,
#  <ppanlp.corpus.PPAText at 0x13ffc3320>,
#  <ppanlp.corpus.PPAText at 0x13ffc3290>,
#  <ppanlp.corpus.PPAText at 0x13ffc3200>,
#  <ppanlp.corpus.PPAText at 0x13ffc34a0>,
#  <ppanlp.corpus.PPAText at 0x13ffc3410>,
#  <ppanlp.corpus.PPAText at 0x13ffc3380>,
#  <ppanlp.corpus.PPAText at 0x13ffc3620>,
#  <ppanlp.corpus.PPAText at 0x13ffc3590>,
#  <ppanlp.corpus.PPAText at 0x13ffc3500>,
#  <ppanlp.corpus.PPAText at 0x13ffc37a0>,
#  <ppanlp.corpus.PPAText at 0x13ffc3710>,
#  <ppanlp.corpus.PPAText at 0x13ffc3680>,
#  <ppanlp.corpus.PPAText at 0x13ffc3920>,
#  <ppanlp.corpus.PPAText at 0x13ffc3890>,
#  <ppanlp.corpus.PPAText at 0x13ffc3800>,
#  <ppanlp.corpus.PPAText at 0x13ffc3ad0>,
#  <ppanlp.corpus.PPAText at 0x13ffc3a40>,
#  <ppanlp.corpus.PPAText at 0x13ffc3980>,
#  <ppanlp.corpus.PPAText at 0x13ffc3c80>,
#  <ppanlp.corpus.PPAText at 0x13ffc3bf0>,
#  <ppanlp.corpus.PPAText at 0x13ffc3b30>,
#  <ppanlp.corpus.PPAText at 0x13ffc3e30>,
#  <ppanlp.corpus.PPAText at 0x13ffc3da0>,
#  <ppanlp.corpus.PPAText at 0x13ffc3ce0>,
#  <ppanlp.corpus.PPAText at 0x13ffc3fe0>,
#  <ppanlp.corpus.PPAText at 0x13ffc3f50>,
#  <ppanlp.corpus.PPAText at 0x13ffc3e90>,
#  <ppanlp.corpus.PPAText at 0x13ffe81d0>,
#  <ppanlp.corpus.PPAText at 0x13ffe8140>,
#  <ppanlp.corpus.PPAText at 0x13ffe8080>,
#  <ppanlp.corpus.PPAText at 0x13ffe8380>,
#  <ppanlp.corpus.PPAText at 0x13ffe82f0>,
#  <ppanlp.corpus.PPAText at 0x13ffe8230>,
#  <ppanlp.corpus.PPAText at 0x13ffe8530>,
#  <ppanlp.corpus.PPAText at 0x13ffe84a0>,
#  <ppanlp.corpus.PPAText at 0x13ffe83e0>,
#  <ppanlp.corpus.PPAText at 0x13ffe86b0>,
#  <ppanlp.corpus.PPAText at 0x13ffe8620>,
#  <ppanlp.corpus.PPAText at 0x13ffe8590>,
#  <ppanlp.corpus.PPAText at 0x13ffe8860>,
#  <ppanlp.corpus.PPAText at 0x13ffe87d0>,
#  <ppanlp.corpus.PPAText at 0x13ffe8710>,
#  <ppanlp.corpus.PPAText at 0x13ffe8a10>,
#  <ppanlp.corpus.PPAText at 0x13ffe8980>,
#  <ppanlp.corpus.PPAText at 0x13ffe88c0>,
#  <ppanlp.corpus.PPAText at 0x13ffe8bc0>,
#  <ppanlp.corpus.PPAText at 0x13ffe8b30>,
#  <ppanlp.corpus.PPAText at 0x13ffe8a70>,
#  <ppanlp.corpus.PPAText at 0x13ffe8d70>,
#  <ppanlp.corpus.PPAText at 0x13ffe8ce0>,
#  <ppanlp.corpus.PPAText at 0x13ffe8c20>,
#  <ppanlp.corpus.PPAText at 0x13ffe8ef0>,
#  <ppanlp.corpus.PPAText at 0x13ffe8e60>,
#  <ppanlp.corpus.PPAText at 0x13ffe8dd0>,
#  <ppanlp.corpus.PPAText at 0x13ffe90a0>,
#  <ppanlp.corpus.PPAText at 0x13ffe9010>,
#  <ppanlp.corpus.PPAText at 0x13ffe8f50>,
#  <ppanlp.corpus.PPAText at 0x13ffe91f0>,
#  <ppanlp.corpus.PPAText at 0x13ffe9160>,
#  <ppanlp.corpus.PPAText at 0x13ffe90d0>,
#  <ppanlp.corpus.PPAText at 0x13ffe9370>,
#  <ppanlp.corpus.PPAText at 0x13ffe92b0>,
#  <ppanlp.corpus.PPAText at 0x13ffe9220>,
#  <ppanlp.corpus.PPAText at 0x13ffe9520>,
#  <ppanlp.corpus.PPAText at 0x13ffe9460>,
#  <ppanlp.corpus.PPAText at 0x13ffe93d0>,
#  <ppanlp.corpus.PPAText at 0x13ffe96d0>,
#  <ppanlp.corpus.PPAText at 0x13ffe9610>,
#  <ppanlp.corpus.PPAText at 0x13ffe9580>,
#  <ppanlp.corpus.PPAText at 0x13ffe9850>,
#  <ppanlp.corpus.PPAText at 0x13ffe97c0>,
#  <ppanlp.corpus.PPAText at 0x13ffe9730>,
#  <ppanlp.corpus.PPAText at 0x13ffe9a60>,
#  <ppanlp.corpus.PPAText at 0x13ffe9940>,
#  <ppanlp.corpus.PPAText at 0x13ffe98b0>,
#  <ppanlp.corpus.PPAText at 0x13ffe9c10>,
#  <ppanlp.corpus.PPAText at 0x13ffe9b50>,
#  <ppanlp.corpus.PPAText at 0x13ffe9ac0>,
#  <ppanlp.corpus.PPAText at 0x13ffe9dc0>,
#  <ppanlp.corpus.PPAText at 0x13ffe9d00>,
#  <ppanlp.corpus.PPAText at 0x13ffe9c70>,
#  <ppanlp.corpus.PPAText at 0x13ffe9f40>,
#  <ppanlp.corpus.PPAText at 0x13ffe9eb0>,
#  <ppanlp.corpus.PPAText at 0x13ffe9e20>,
#  <ppanlp.corpus.PPAText at 0x13ffea0c0>,
#  <ppanlp.corpus.PPAText at 0x13ffea030>,
#  <ppanlp.corpus.PPAText at 0x13ffe9fa0>,
#  <ppanlp.corpus.PPAText at 0x13ffea240>,
#  <ppanlp.corpus.PPAText at 0x13ffea1b0>,
#  <ppanlp.corpus.PPAText at 0x13ffea120>,
#  <ppanlp.corpus.PPAText at 0x13ffea3c0>,
#  <ppanlp.corpus.PPAText at 0x13ffea2d0>,
#  <ppanlp.corpus.PPAText at 0x13ffea5d0>,
#  <ppanlp.corpus.PPAText at 0x13ffea510>,
#  <ppanlp.corpus.PPAText at 0x13ffea450>,
#  <ppanlp.corpus.PPAText at 0x13ffea750>,
#  <ppanlp.corpus.PPAText at 0x13ffea6c0>,
#  <ppanlp.corpus.PPAText at 0x13ffea630>,
#  <ppanlp.corpus.PPAText at 0x13ffea900>,
#  <ppanlp.corpus.PPAText at 0x13ffea810>,
#  <ppanlp.corpus.PPAText at 0x13ffea780>,
#  <ppanlp.corpus.PPAText at 0x13ffeaa50>,
#  <ppanlp.corpus.PPAText at 0x13ffea960>,
#  <ppanlp.corpus.PPAText at 0x13ffeac00>,
#  <ppanlp.corpus.PPAText at 0x13ffeab70>,
#  <ppanlp.corpus.PPAText at 0x13ffeaae0>,
#  <ppanlp.corpus.PPAText at 0x13ffead80>,
#  <ppanlp.corpus.PPAText at 0x13ffeacf0>,
#  <ppanlp.corpus.PPAText at 0x13ffeac60>,
#  <ppanlp.corpus.PPAText at 0x13ffeaf00>,
#  <ppanlp.corpus.PPAText at 0x13ffeae70>,
#  <ppanlp.corpus.PPAText at 0x13ffeade0>,
#  <ppanlp.corpus.PPAText at 0x13ffeb0b0>,
#  <ppanlp.corpus.PPAText at 0x13ffeb020>,
#  <ppanlp.corpus.PPAText at 0x13ffeaf60>,
#  <ppanlp.corpus.PPAText at 0x13ffeb260>,
#  <ppanlp.corpus.PPAText at 0x13ffeb1d0>,
#  <ppanlp.corpus.PPAText at 0x13ffeb110>,
#  <ppanlp.corpus.PPAText at 0x13ffeb410>,
#  <ppanlp.corpus.PPAText at 0x13ffeb380>,
#  <ppanlp.corpus.PPAText at 0x13ffeb2c0>,
#  <ppanlp.corpus.PPAText at 0x13ffeb590>,
#  <ppanlp.corpus.PPAText at 0x13ffeb4d0>,
#  <ppanlp.corpus.PPAText at 0x13ffeb440>,
#  <ppanlp.corpus.PPAText at 0x13ffeb6b0>,
#  <ppanlp.corpus.PPAText at 0x13ffeb5f0>,
#  <ppanlp.corpus.PPAText at 0x13ffeb890>,
#  <ppanlp.corpus.PPAText at 0x13ffeb7d0>,
#  <ppanlp.corpus.PPAText at 0x13ffeb740>,
#  <ppanlp.corpus.PPAText at 0x13ffeb9b0>,
#  <ppanlp.corpus.PPAText at 0x13ffeb8f0>,
#  <ppanlp.corpus.PPAText at 0x13ffebb90>,
#  <ppanlp.corpus.PPAText at 0x13ffebad0>,
#  <ppanlp.corpus.PPAText at 0x13ffeba40>,
#  <ppanlp.corpus.PPAText at 0x13ffebcb0>,
#  <ppanlp.corpus.PPAText at 0x13ffebbf0>,
#  <ppanlp.corpus.PPAText at 0x13ffebec0>,
#  <ppanlp.corpus.PPAText at 0x13ffebe00>,
#  <ppanlp.corpus.PPAText at 0x13ffebd70>,
#  <ppanlp.corpus.PPAText at 0x13ffebfe0>,
#  <ppanlp.corpus.PPAText at 0x13ffebf20>,
#  <ppanlp.corpus.PPAText at 0x140008080>,
#  <ppanlp.corpus.PPAText at 0x1400081a0>,
#  <ppanlp.corpus.PPAText at 0x1400080e0>,
#  <ppanlp.corpus.PPAText at 0x140008380>,
#  <ppanlp.corpus.PPAText at 0x1400082c0>,
#  <ppanlp.corpus.PPAText at 0x140008230>,
#  <ppanlp.corpus.PPAText at 0x1400084a0>,
#  <ppanlp.corpus.PPAText at 0x1400083e0>,
#  <ppanlp.corpus.PPAText at 0x140008680>,
#  <ppanlp.corpus.PPAText at 0x1400085c0>,
#  <ppanlp.corpus.PPAText at 0x140008530>,
#  <ppanlp.corpus.PPAText at 0x1400087a0>,
#  <ppanlp.corpus.PPAText at 0x1400086e0>,
#  <ppanlp.corpus.PPAText at 0x140008980>,
#  <ppanlp.corpus.PPAText at 0x1400088c0>,
#  <ppanlp.corpus.PPAText at 0x140008830>,
#  <ppanlp.corpus.PPAText at 0x140008ad0>,
#  <ppanlp.corpus.PPAText at 0x1400089e0>,
#  <ppanlp.corpus.PPAText at 0x140008ce0>,
#  <ppanlp.corpus.PPAText at 0x140008bf0>,
#  <ppanlp.corpus.PPAText at 0x140008b60>,
#  <ppanlp.corpus.PPAText at 0x140008e60>,
#  <ppanlp.corpus.PPAText at 0x140008da0>,
#  <ppanlp.corpus.PPAText at 0x140008d10>,
#  <ppanlp.corpus.PPAText at 0x140009010>,
#  <ppanlp.corpus.PPAText at 0x140008f50>,
#  <ppanlp.corpus.PPAText at 0x140008ec0>,
#  <ppanlp.corpus.PPAText at 0x140009190>,
#  <ppanlp.corpus.PPAText at 0x140009100>,
#  <ppanlp.corpus.PPAText at 0x140009070>,
#  <ppanlp.corpus.PPAText at 0x140009340>,
#  <ppanlp.corpus.PPAText at 0x1400092b0>,
#  <ppanlp.corpus.PPAText at 0x140009220>,
#  <ppanlp.corpus.PPAText at 0x1400094f0>,
#  <ppanlp.corpus.PPAText at 0x140009460>,
#  <ppanlp.corpus.PPAText at 0x1400093d0>,
#  <ppanlp.corpus.PPAText at 0x1400096d0>,
#  <ppanlp.corpus.PPAText at 0x140009610>,
#  <ppanlp.corpus.PPAText at 0x140009580>,
#  <ppanlp.corpus.PPAText at 0x140009880>,
#  <ppanlp.corpus.PPAText at 0x1400097c0>,
#  <ppanlp.corpus.PPAText at 0x140009730>,
#  <ppanlp.corpus.PPAText at 0x140009a30>,
#  <ppanlp.corpus.PPAText at 0x140009970>,
#  <ppanlp.corpus.PPAText at 0x1400098e0>,
#  <ppanlp.corpus.PPAText at 0x140009be0>,
#  <ppanlp.corpus.PPAText at 0x140009af0>,
#  <ppanlp.corpus.PPAText at 0x140009e80>,
#  <ppanlp.corpus.PPAText at 0x140009d60>,
#  <ppanlp.corpus.PPAText at 0x140009ca0>,
#  <ppanlp.corpus.PPAText at 0x14000a0c0>,
#  <ppanlp.corpus.PPAText at 0x140009fa0>,
#  <ppanlp.corpus.PPAText at 0x140009ee0>,
#  <ppanlp.corpus.PPAText at 0x14000a270>,
#  <ppanlp.corpus.PPAText at 0x14000a1e0>,
#  <ppanlp.corpus.PPAText at 0x14000a120>,
#  <ppanlp.corpus.PPAText at 0x14000a420>,
#  <ppanlp.corpus.PPAText at 0x14000a360>,
#  <ppanlp.corpus.PPAText at 0x14000a2d0>,
#  <ppanlp.corpus.PPAText at 0x14000a5a0>,
#  <ppanlp.corpus.PPAText at 0x14000a510>,
#  <ppanlp.corpus.PPAText at 0x14000a480>,
#  <ppanlp.corpus.PPAText at 0x14000a720>,
#  <ppanlp.corpus.PPAText at 0x14000a690>,
#  <ppanlp.corpus.PPAText at 0x14000a600>,
#  <ppanlp.corpus.PPAText at 0x14000a8d0>,
#  <ppanlp.corpus.PPAText at 0x14000a840>,
#  <ppanlp.corpus.PPAText at 0x14000a780>,
#  <ppanlp.corpus.PPAText at 0x14000aa80>,
#  <ppanlp.corpus.PPAText at 0x14000a9f0>,
#  <ppanlp.corpus.PPAText at 0x14000a930>,
#  <ppanlp.corpus.PPAText at 0x14000ac00>,
#  <ppanlp.corpus.PPAText at 0x14000ab70>,
#  <ppanlp.corpus.PPAText at 0x14000aae0>,
#  <ppanlp.corpus.PPAText at 0x14000ad80>,
#  <ppanlp.corpus.PPAText at 0x14000acf0>,
#  <ppanlp.corpus.PPAText at 0x14000ac60>,
#  <ppanlp.corpus.PPAText at 0x14000af00>,
#  <ppanlp.corpus.PPAText at 0x14000ae40>,
#  <ppanlp.corpus.PPAText at 0x14000adb0>,
#  <ppanlp.corpus.PPAText at 0x14000b0e0>,
#  <ppanlp.corpus.PPAText at 0x14000afc0>,
#  <ppanlp.corpus.PPAText at 0x14000af30>,
#  <ppanlp.corpus.PPAText at 0x14000b2c0>,
#  <ppanlp.corpus.PPAText at 0x14000b1d0>,
#  <ppanlp.corpus.PPAText at 0x14000b140>,
#  <ppanlp.corpus.PPAText at 0x14000b440>,
#  <ppanlp.corpus.PPAText at 0x14000b3b0>,
#  <ppanlp.corpus.PPAText at 0x14000b320>,
#  <ppanlp.corpus.PPAText at 0x14000b5f0>,
#  <ppanlp.corpus.PPAText at 0x14000b530>,
#  <ppanlp.corpus.PPAText at 0x14000b4a0>,
#  <ppanlp.corpus.PPAText at 0x14000b7d0>,
#  <ppanlp.corpus.PPAText at 0x14000b6e0>,
#  <ppanlp.corpus.PPAText at 0x14000b650>,
#  <ppanlp.corpus.PPAText at 0x14000b9b0>,
#  <ppanlp.corpus.PPAText at 0x14000b8f0>,
#  <ppanlp.corpus.PPAText at 0x14000b860>,
#  <ppanlp.corpus.PPAText at 0x14000bb90>,
#  <ppanlp.corpus.PPAText at 0x14000bad0>,
#  <ppanlp.corpus.PPAText at 0x14000ba40>,
#  <ppanlp.corpus.PPAText at 0x14000bd40>,
#  <ppanlp.corpus.PPAText at 0x14000bcb0>,
#  <ppanlp.corpus.PPAText at 0x14000bc20>,
#  <ppanlp.corpus.PPAText at 0x14000bec0>,
#  <ppanlp.corpus.PPAText at 0x14000be30>,
#  <ppanlp.corpus.PPAText at 0x14000bda0>,
#  <ppanlp.corpus.PPAText at 0x14000bfb0>,
#  <ppanlp.corpus.PPAText at 0x14000bf20>,
#  <ppanlp.corpus.PPAText at 0x14001c080>,
#  <ppanlp.corpus.PPAText at 0x14001c230>,
#  <ppanlp.corpus.PPAText at 0x14001c170>,
#  <ppanlp.corpus.PPAText at 0x14001c0e0>,
#  <ppanlp.corpus.PPAText at 0x14001c3e0>,
#  <ppanlp.corpus.PPAText at 0x14001c320>,
#  <ppanlp.corpus.PPAText at 0x14001c290>,
#  <ppanlp.corpus.PPAText at 0x14001c560>,
#  <ppanlp.corpus.PPAText at 0x14001c4d0>,
#  <ppanlp.corpus.PPAText at 0x14001c440>,
#  <ppanlp.corpus.PPAText at 0x14001c6e0>,
#  <ppanlp.corpus.PPAText at 0x14001c650>,
#  <ppanlp.corpus.PPAText at 0x14001c5c0>,
#  <ppanlp.corpus.PPAText at 0x14001c860>,
#  <ppanlp.corpus.PPAText at 0x14001c7d0>,
#  <ppanlp.corpus.PPAText at 0x14001c740>,
#  <ppanlp.corpus.PPAText at 0x14001ca10>,
#  <ppanlp.corpus.PPAText at 0x14001c950>,
#  <ppanlp.corpus.PPAText at 0x14001c8c0>,
#  <ppanlp.corpus.PPAText at 0x14001cb90>,
#  <ppanlp.corpus.PPAText at 0x14001cb00>,
#  <ppanlp.corpus.PPAText at 0x14001ca70>,
#  <ppanlp.corpus.PPAText at 0x14001cda0>,
#  <ppanlp.corpus.PPAText at 0x14001cc80>,
#  <ppanlp.corpus.PPAText at 0x14001cbf0>,
#  <ppanlp.corpus.PPAText at 0x14001cf50>,
#  <ppanlp.corpus.PPAText at 0x14001ce90>,
#  <ppanlp.corpus.PPAText at 0x14001ce00>,
#  <ppanlp.corpus.PPAText at 0x14001d100>,
#  <ppanlp.corpus.PPAText at 0x14001d040>,
#  <ppanlp.corpus.PPAText at 0x14001cfb0>,
#  <ppanlp.corpus.PPAText at 0x14001d2b0>,
#  <ppanlp.corpus.PPAText at 0x14001d1f0>,
#  <ppanlp.corpus.PPAText at 0x14001d160>,
#  <ppanlp.corpus.PPAText at 0x14001d400>,
#  <ppanlp.corpus.PPAText at 0x14001d340>,
#  <ppanlp.corpus.PPAText at 0x14001d610>,
#  <ppanlp.corpus.PPAText at 0x14001d520>,
#  <ppanlp.corpus.PPAText at 0x14001d490>,
#  <ppanlp.corpus.PPAText at 0x14001d760>,
#  <ppanlp.corpus.PPAText at 0x14001d670>,
#  <ppanlp.corpus.PPAText at 0x14001d970>,
#  <ppanlp.corpus.PPAText at 0x14001d8e0>,
#  <ppanlp.corpus.PPAText at 0x14001d820>,
#  <ppanlp.corpus.PPAText at 0x14001dac0>,
#  <ppanlp.corpus.PPAText at 0x14001da30>,
#  <ppanlp.corpus.PPAText at 0x14001d9a0>,
#  <ppanlp.corpus.PPAText at 0x14001dc10>,
#  <ppanlp.corpus.PPAText at 0x14001db80>,
#  <ppanlp.corpus.PPAText at 0x14001daf0>,
#  <ppanlp.corpus.PPAText at 0x14001dd60>,
#  <ppanlp.corpus.PPAText at 0x14001dca0>,
#  <ppanlp.corpus.PPAText at 0x14001df10>,
#  <ppanlp.corpus.PPAText at 0x14001de80>,
#  <ppanlp.corpus.PPAText at 0x14001ddf0>,
#  <ppanlp.corpus.PPAText at 0x14001e090>,
#  <ppanlp.corpus.PPAText at 0x14001e000>,
#  <ppanlp.corpus.PPAText at 0x14001df70>,
#  <ppanlp.corpus.PPAText at 0x14001e210>,
#  <ppanlp.corpus.PPAText at 0x14001e180>,
#  <ppanlp.corpus.PPAText at 0x14001e0f0>,
#  <ppanlp.corpus.PPAText at 0x14001e390>,
#  <ppanlp.corpus.PPAText at 0x14001e300>,
#  <ppanlp.corpus.PPAText at 0x14001e270>,
#  <ppanlp.corpus.PPAText at 0x14001e5a0>,
#  <ppanlp.corpus.PPAText at 0x14001e4b0>,
#  <ppanlp.corpus.PPAText at 0x14001e3f0>,
#  <ppanlp.corpus.PPAText at 0x14001e750>,
#  <ppanlp.corpus.PPAText at 0x14001e6c0>,
#  <ppanlp.corpus.PPAText at 0x14001e600>,
#  <ppanlp.corpus.PPAText at 0x14001e900>,
#  <ppanlp.corpus.PPAText at 0x14001e870>,
#  <ppanlp.corpus.PPAText at 0x14001e7b0>,
#  <ppanlp.corpus.PPAText at 0x14001eab0>,
#  <ppanlp.corpus.PPAText at 0x14001ea20>,
#  <ppanlp.corpus.PPAText at 0x14001e960>,
#  <ppanlp.corpus.PPAText at 0x14001ec60>,
#  <ppanlp.corpus.PPAText at 0x14001ebd0>,
#  <ppanlp.corpus.PPAText at 0x14001eb10>,
#  <ppanlp.corpus.PPAText at 0x14001ede0>,
#  <ppanlp.corpus.PPAText at 0x14001ed20>,
#  <ppanlp.corpus.PPAText at 0x14001ec90>,
#  <ppanlp.corpus.PPAText at 0x14001ef30>,
#  <ppanlp.corpus.PPAText at 0x14001eea0>,
#  <ppanlp.corpus.PPAText at 0x14001ee10>,
#  <ppanlp.corpus.PPAText at 0x14001f0e0>,
#  <ppanlp.corpus.PPAText at 0x14001f020>,
#  <ppanlp.corpus.PPAText at 0x14001ef90>,
#  <ppanlp.corpus.PPAText at 0x14001f230>,
#  <ppanlp.corpus.PPAText at 0x14001f170>,
#  <ppanlp.corpus.PPAText at 0x14001f3e0>,
#  <ppanlp.corpus.PPAText at 0x14001f350>,
#  <ppanlp.corpus.PPAText at 0x14001f2c0>,
#  <ppanlp.corpus.PPAText at 0x14001f560>,
#  <ppanlp.corpus.PPAText at 0x14001f4a0>,
#  <ppanlp.corpus.PPAText at 0x14001f410>,
#  <ppanlp.corpus.PPAText at 0x14001f6e0>,
#  <ppanlp.corpus.PPAText at 0x14001f620>,
#  <ppanlp.corpus.PPAText at 0x14001f590>,
#  <ppanlp.corpus.PPAText at 0x14001f890>,
#  <ppanlp.corpus.PPAText at 0x14001f7d0>,
#  <ppanlp.corpus.PPAText at 0x14001f740>,
#  <ppanlp.corpus.PPAText at 0x14001fa40>,
#  <ppanlp.corpus.PPAText at 0x14001f980>,
#  <ppanlp.corpus.PPAText at 0x14001f8f0>,
#  <ppanlp.corpus.PPAText at 0x14001fbf0>,
#  <ppanlp.corpus.PPAText at 0x14001fb30>,
#  <ppanlp.corpus.PPAText at 0x14001faa0>,
#  <ppanlp.corpus.PPAText at 0x14001fe00>,
#  <ppanlp.corpus.PPAText at 0x14001fce0>,
#  <ppanlp.corpus.PPAText at 0x14001fc50>,
#  <ppanlp.corpus.PPAText at 0x14001ffb0>,
#  <ppanlp.corpus.PPAText at 0x14001fef0>,
#  <ppanlp.corpus.PPAText at 0x14001fe60>,
#  <ppanlp.corpus.PPAText at 0x140048170>,
#  <ppanlp.corpus.PPAText at 0x140048080>,
#  <ppanlp.corpus.PPAText at 0x140048350>,
#  <ppanlp.corpus.PPAText at 0x1400482c0>,
#  <ppanlp.corpus.PPAText at 0x140048200>,
#  <ppanlp.corpus.PPAText at 0x1400484d0>,
#  <ppanlp.corpus.PPAText at 0x140048440>,
#  <ppanlp.corpus.PPAText at 0x1400483b0>,
#  <ppanlp.corpus.PPAText at 0x140048650>,
#  <ppanlp.corpus.PPAText at 0x1400485c0>,
#  <ppanlp.corpus.PPAText at 0x140048530>,
#  <ppanlp.corpus.PPAText at 0x1400487d0>,
#  <ppanlp.corpus.PPAText at 0x140048740>,
#  <ppanlp.corpus.PPAText at 0x1400486b0>,
#  <ppanlp.corpus.PPAText at 0x140048950>,
#  <ppanlp.corpus.PPAText at 0x1400488c0>,
#  <ppanlp.corpus.PPAText at 0x140048830>,
#  <ppanlp.corpus.PPAText at 0x140048b00>,
#  <ppanlp.corpus.PPAText at 0x140048a70>,
#  <ppanlp.corpus.PPAText at 0x1400489b0>,
#  <ppanlp.corpus.PPAText at 0x140048cb0>,
#  <ppanlp.corpus.PPAText at 0x140048c20>,
#  <ppanlp.corpus.PPAText at 0x140048b60>,
#  <ppanlp.corpus.PPAText at 0x140048ec0>,
#  <ppanlp.corpus.PPAText at 0x140048dd0>,
#  <ppanlp.corpus.PPAText at 0x140048d10>,
#  <ppanlp.corpus.PPAText at 0x140049040>,
#  <ppanlp.corpus.PPAText at 0x140048fb0>,
#  <ppanlp.corpus.PPAText at 0x140048f20>,
#  <ppanlp.corpus.PPAText at 0x1400491c0>,
#  <ppanlp.corpus.PPAText at 0x140049130>,
#  <ppanlp.corpus.PPAText at 0x1400490a0>,
#  <ppanlp.corpus.PPAText at 0x140049370>,
#  <ppanlp.corpus.PPAText at 0x1400492e0>,
#  <ppanlp.corpus.PPAText at 0x140049220>,
#  <ppanlp.corpus.PPAText at 0x1400494f0>,
#  <ppanlp.corpus.PPAText at 0x140049460>,
#  <ppanlp.corpus.PPAText at 0x1400493d0>,
#  <ppanlp.corpus.PPAText at 0x140049670>,
#  <ppanlp.corpus.PPAText at 0x1400495b0>,
#  <ppanlp.corpus.PPAText at 0x140049520>,
#  <ppanlp.corpus.PPAText at 0x1400497f0>,
#  <ppanlp.corpus.PPAText at 0x140049730>,
#  <ppanlp.corpus.PPAText at 0x1400496a0>,
#  <ppanlp.corpus.PPAText at 0x1400499d0>,
#  <ppanlp.corpus.PPAText at 0x140049910>,
#  <ppanlp.corpus.PPAText at 0x140049880>,
#  <ppanlp.corpus.PPAText at 0x140049bb0>,
#  <ppanlp.corpus.PPAText at 0x140049af0>,
#  <ppanlp.corpus.PPAText at 0x140049a60>,
#  <ppanlp.corpus.PPAText at 0x140049d90>,
#  <ppanlp.corpus.PPAText at 0x140049cd0>,
#  <ppanlp.corpus.PPAText at 0x140049c40>,
#  <ppanlp.corpus.PPAText at 0x140049f70>,
#  <ppanlp.corpus.PPAText at 0x140049eb0>,
#  <ppanlp.corpus.PPAText at 0x140049e20>,
#  <ppanlp.corpus.PPAText at 0x14004a150>,
#  <ppanlp.corpus.PPAText at 0x14004a090>,
#  <ppanlp.corpus.PPAText at 0x14004a000>,
#  <ppanlp.corpus.PPAText at 0x14004a330>,
#  <ppanlp.corpus.PPAText at 0x14004a270>,
#  <ppanlp.corpus.PPAText at 0x14004a1e0>,
#  <ppanlp.corpus.PPAText at 0x14004a510>,
#  <ppanlp.corpus.PPAText at 0x14004a450>,
#  <ppanlp.corpus.PPAText at 0x14004a3c0>,
#  <ppanlp.corpus.PPAText at 0x14004a6f0>,
#  <ppanlp.corpus.PPAText at 0x14004a630>,
#  <ppanlp.corpus.PPAText at 0x14004a5a0>,
#  <ppanlp.corpus.PPAText at 0x14004a8d0>,
#  <ppanlp.corpus.PPAText at 0x14004a810>,
#  <ppanlp.corpus.PPAText at 0x14004a780>,
#  <ppanlp.corpus.PPAText at 0x14004aab0>,
#  <ppanlp.corpus.PPAText at 0x14004a9f0>,
#  <ppanlp.corpus.PPAText at 0x14004a960>,
#  <ppanlp.corpus.PPAText at 0x14004ac90>,
#  <ppanlp.corpus.PPAText at 0x14004abd0>,
#  <ppanlp.corpus.PPAText at 0x14004ab40>,
#  <ppanlp.corpus.PPAText at 0x14004ae70>,
#  <ppanlp.corpus.PPAText at 0x14004adb0>,
#  <ppanlp.corpus.PPAText at 0x14004ad20>,
#  <ppanlp.corpus.PPAText at 0x14004b050>,
#  <ppanlp.corpus.PPAText at 0x14004af90>,
#  <ppanlp.corpus.PPAText at 0x14004af00>,
#  <ppanlp.corpus.PPAText at 0x14004b230>,
#  <ppanlp.corpus.PPAText at 0x14004b170>,
#  <ppanlp.corpus.PPAText at 0x14004b0e0>,
#  <ppanlp.corpus.PPAText at 0x14004b410>,
#  <ppanlp.corpus.PPAText at 0x14004b350>,
#  <ppanlp.corpus.PPAText at 0x14004b2c0>,
#  <ppanlp.corpus.PPAText at 0x14004b5c0>,
#  <ppanlp.corpus.PPAText at 0x14004b530>,
#  <ppanlp.corpus.PPAText at 0x14004b4a0>,
#  <ppanlp.corpus.PPAText at 0x14004b740>,
#  <ppanlp.corpus.PPAText at 0x14004b6b0>,
#  <ppanlp.corpus.PPAText at 0x14004b620>,
#  <ppanlp.corpus.PPAText at 0x14004b8f0>,
#  <ppanlp.corpus.PPAText at 0x14004b830>,
#  <ppanlp.corpus.PPAText at 0x14004b7a0>,
#  <ppanlp.corpus.PPAText at 0x14004bad0>,
#  <ppanlp.corpus.PPAText at 0x14004ba10>,
#  <ppanlp.corpus.PPAText at 0x14004b980>,
#  <ppanlp.corpus.PPAText at 0x14004bc80>,
#  <ppanlp.corpus.PPAText at 0x14004bbc0>,
#  <ppanlp.corpus.PPAText at 0x14004bb30>,
#  <ppanlp.corpus.PPAText at 0x14004be00>,
#  <ppanlp.corpus.PPAText at 0x14004bd70>,
#  <ppanlp.corpus.PPAText at 0x14004bce0>,
#  <ppanlp.corpus.PPAText at 0x14004bfb0>,
#  <ppanlp.corpus.PPAText at 0x14004bef0>,
#  <ppanlp.corpus.PPAText at 0x14004be60>,
#  <ppanlp.corpus.PPAText at 0x1400681a0>,
#  <ppanlp.corpus.PPAText at 0x1400680e0>,
#  <ppanlp.corpus.PPAText at 0x140068050>,
#  <ppanlp.corpus.PPAText at 0x140068350>,
#  <ppanlp.corpus.PPAText at 0x140068290>,
#  <ppanlp.corpus.PPAText at 0x140068200>,
#  <ppanlp.corpus.PPAText at 0x1400684d0>,
#  <ppanlp.corpus.PPAText at 0x140068440>,
#  <ppanlp.corpus.PPAText at 0x1400683b0>,
#  <ppanlp.corpus.PPAText at 0x140068680>,
#  <ppanlp.corpus.PPAText at 0x1400685c0>,
#  <ppanlp.corpus.PPAText at 0x140068530>,
#  <ppanlp.corpus.PPAText at 0x140068800>,
#  <ppanlp.corpus.PPAText at 0x140068710>,
#  <ppanlp.corpus.PPAText at 0x1400689e0>,
#  <ppanlp.corpus.PPAText at 0x140068950>,
#  <ppanlp.corpus.PPAText at 0x140068890>,
#  <ppanlp.corpus.PPAText at 0x140068b90>,
#  <ppanlp.corpus.PPAText at 0x140068b00>,
#  <ppanlp.corpus.PPAText at 0x140068a40>,
#  <ppanlp.corpus.PPAText at 0x140068d40>,
#  <ppanlp.corpus.PPAText at 0x140068cb0>,
#  <ppanlp.corpus.PPAText at 0x140068bf0>,
#  <ppanlp.corpus.PPAText at 0x140068ec0>,
#  <ppanlp.corpus.PPAText at 0x140068e00>,
#  <ppanlp.corpus.PPAText at 0x140068d70>,
#  <ppanlp.corpus.PPAText at 0x140069040>,
#  <ppanlp.corpus.PPAText at 0x140068f80>,
#  <ppanlp.corpus.PPAText at 0x140068ef0>,
#  <ppanlp.corpus.PPAText at 0x1400691f0>,
#  <ppanlp.corpus.PPAText at 0x140069130>,
#  <ppanlp.corpus.PPAText at 0x1400690a0>,
#  <ppanlp.corpus.PPAText at 0x140069370>,
#  <ppanlp.corpus.PPAText at 0x1400692e0>,
#  <ppanlp.corpus.PPAText at 0x140069250>,
#  <ppanlp.corpus.PPAText at 0x1400694f0>,
#  <ppanlp.corpus.PPAText at 0x140069460>,
#  <ppanlp.corpus.PPAText at 0x1400693d0>,
#  <ppanlp.corpus.PPAText at 0x140069640>,
#  <ppanlp.corpus.PPAText at 0x140069580>,
#  <ppanlp.corpus.PPAText at 0x140069820>,
#  <ppanlp.corpus.PPAText at 0x140069790>,
#  <ppanlp.corpus.PPAText at 0x140069700>,
#  <ppanlp.corpus.PPAText at 0x140069a30>,
#  <ppanlp.corpus.PPAText at 0x140069970>,
#  <ppanlp.corpus.PPAText at 0x140069880>,
#  <ppanlp.corpus.PPAText at 0x140069c10>,
#  <ppanlp.corpus.PPAText at 0x140069b50>,
#  <ppanlp.corpus.PPAText at 0x140069a90>,
#  <ppanlp.corpus.PPAText at 0x140069df0>,
#  <ppanlp.corpus.PPAText at 0x140069d30>,
#  <ppanlp.corpus.PPAText at 0x140069c70>,
#  <ppanlp.corpus.PPAText at 0x140069fd0>,
#  <ppanlp.corpus.PPAText at 0x140069f10>,
#  <ppanlp.corpus.PPAText at 0x140069e50>,
#  <ppanlp.corpus.PPAText at 0x14006a180>,
#  <ppanlp.corpus.PPAText at 0x14006a0f0>,
#  <ppanlp.corpus.PPAText at 0x14006a030>,
#  <ppanlp.corpus.PPAText at 0x14006a330>,
#  <ppanlp.corpus.PPAText at 0x14006a2a0>,
#  <ppanlp.corpus.PPAText at 0x14006a1e0>,
#  <ppanlp.corpus.PPAText at 0x14006a4e0>,
#  <ppanlp.corpus.PPAText at 0x14006a450>,
#  <ppanlp.corpus.PPAText at 0x14006a390>,
#  <ppanlp.corpus.PPAText at 0x14006a690>,
#  <ppanlp.corpus.PPAText at 0x14006a600>,
#  <ppanlp.corpus.PPAText at 0x14006a540>,
#  <ppanlp.corpus.PPAText at 0x14006a840>,
#  <ppanlp.corpus.PPAText at 0x14006a7b0>,
#  <ppanlp.corpus.PPAText at 0x14006a6f0>,
#  <ppanlp.corpus.PPAText at 0x14006a9f0>,
#  <ppanlp.corpus.PPAText at 0x14006a960>,
#  <ppanlp.corpus.PPAText at 0x14006a8a0>,
#  <ppanlp.corpus.PPAText at 0x14006aba0>,
#  <ppanlp.corpus.PPAText at 0x14006ab10>,
#  <ppanlp.corpus.PPAText at 0x14006aa50>,
#  <ppanlp.corpus.PPAText at 0x14006ad50>,
#  <ppanlp.corpus.PPAText at 0x14006acc0>,
#  <ppanlp.corpus.PPAText at 0x14006ac00>,
#  <ppanlp.corpus.PPAText at 0x14006af00>,
#  <ppanlp.corpus.PPAText at 0x14006ae70>,
#  <ppanlp.corpus.PPAText at 0x14006adb0>,
#  <ppanlp.corpus.PPAText at 0x14006b0b0>,
#  <ppanlp.corpus.PPAText at 0x14006b020>,
#  <ppanlp.corpus.PPAText at 0x14006af60>,
#  <ppanlp.corpus.PPAText at 0x14006b230>,
#  <ppanlp.corpus.PPAText at 0x14006b1a0>,
#  <ppanlp.corpus.PPAText at 0x14006b110>,
#  <ppanlp.corpus.PPAText at 0x14006b440>,
#  <ppanlp.corpus.PPAText at 0x14006b350>,
#  <ppanlp.corpus.PPAText at 0x14006b290>,
#  <ppanlp.corpus.PPAText at 0x14006b650>,
#  <ppanlp.corpus.PPAText at 0x14006b560>,
#  <ppanlp.corpus.PPAText at 0x14006b4a0>,
#  <ppanlp.corpus.PPAText at 0x14006b860>,
#  <ppanlp.corpus.PPAText at 0x14006b770>,
#  <ppanlp.corpus.PPAText at 0x14006b6b0>,
#  <ppanlp.corpus.PPAText at 0x14006ba10>,
#  <ppanlp.corpus.PPAText at 0x14006b980>,
#  <ppanlp.corpus.PPAText at 0x14006b8c0>,
#  <ppanlp.corpus.PPAText at 0x14006bbc0>,
#  <ppanlp.corpus.PPAText at 0x14006bb30>,
#  <ppanlp.corpus.PPAText at 0x14006ba70>,
#  <ppanlp.corpus.PPAText at 0x14006bd40>,
#  <ppanlp.corpus.PPAText at 0x14006bcb0>,
#  <ppanlp.corpus.PPAText at 0x14006bc20>,
#  <ppanlp.corpus.PPAText at 0x14006bec0>,
#  <ppanlp.corpus.PPAText at 0x14006be30>,
#  <ppanlp.corpus.PPAText at 0x14006bda0>,
#  <ppanlp.corpus.PPAText at 0x14006bfe0>,
#  <ppanlp.corpus.PPAText at 0x14006bf20>,
#  <ppanlp.corpus.PPAText at 0x1400840b0>,
#  <ppanlp.corpus.PPAText at 0x1400842c0>,
#  <ppanlp.corpus.PPAText at 0x1400841d0>,
#  <ppanlp.corpus.PPAText at 0x140084110>,
#  <ppanlp.corpus.PPAText at 0x1400844d0>,
#  <ppanlp.corpus.PPAText at 0x1400843e0>,
#  <ppanlp.corpus.PPAText at 0x140084320>,
#  <ppanlp.corpus.PPAText at 0x140084710>,
#  <ppanlp.corpus.PPAText at 0x1400845f0>,
#  <ppanlp.corpus.PPAText at 0x140084530>,
#  <ppanlp.corpus.PPAText at 0x1400848c0>,
#  <ppanlp.corpus.PPAText at 0x140084830>,
#  <ppanlp.corpus.PPAText at 0x140084770>,
#  <ppanlp.corpus.PPAText at 0x140084ad0>,
#  <ppanlp.corpus.PPAText at 0x1400849e0>,
#  <ppanlp.corpus.PPAText at 0x140084920>,
#  <ppanlp.corpus.PPAText at 0x140084c80>,
#  <ppanlp.corpus.PPAText at 0x140084bf0>,
#  <ppanlp.corpus.PPAText at 0x140084b30>,
#  <ppanlp.corpus.PPAText at 0x140084e30>,
#  <ppanlp.corpus.PPAText at 0x140084d70>,
#  <ppanlp.corpus.PPAText at 0x140084ce0>,
#  <ppanlp.corpus.PPAText at 0x140084fe0>,
#  <ppanlp.corpus.PPAText at 0x140084f20>,
#  <ppanlp.corpus.PPAText at 0x140084e90>,
#  <ppanlp.corpus.PPAText at 0x1400851f0>,
#  <ppanlp.corpus.PPAText at 0x140085130>,
#  <ppanlp.corpus.PPAText at 0x140085040>,
#  <ppanlp.corpus.PPAText at 0x1400853a0>,
#  <ppanlp.corpus.PPAText at 0x140085310>,
#  <ppanlp.corpus.PPAText at 0x140085250>,
#  <ppanlp.corpus.PPAText at 0x140085580>,
#  <ppanlp.corpus.PPAText at 0x1400854c0>,
#  <ppanlp.corpus.PPAText at 0x140085400>,
#  <ppanlp.corpus.PPAText at 0x140085730>,
#  <ppanlp.corpus.PPAText at 0x1400856a0>,
#  <ppanlp.corpus.PPAText at 0x1400855e0>,
#  <ppanlp.corpus.PPAText at 0x1400858e0>,
#  <ppanlp.corpus.PPAText at 0x140085850>,
#  <ppanlp.corpus.PPAText at 0x140085790>,
#  <ppanlp.corpus.PPAText at 0x140085a90>,
#  <ppanlp.corpus.PPAText at 0x140085a00>,
#  <ppanlp.corpus.PPAText at 0x140085940>,
#  <ppanlp.corpus.PPAText at 0x140085c40>,
#  <ppanlp.corpus.PPAText at 0x140085bb0>,
#  <ppanlp.corpus.PPAText at 0x140085af0>,
#  <ppanlp.corpus.PPAText at 0x140085df0>,
#  <ppanlp.corpus.PPAText at 0x140085d60>,
#  <ppanlp.corpus.PPAText at 0x140085ca0>,
#  <ppanlp.corpus.PPAText at 0x140085f70>,
#  <ppanlp.corpus.PPAText at 0x140085eb0>,
#  <ppanlp.corpus.PPAText at 0x140085e20>,
#  <ppanlp.corpus.PPAText at 0x1400860f0>,
#  <ppanlp.corpus.PPAText at 0x140086030>,
#  <ppanlp.corpus.PPAText at 0x140085fa0>,
#  <ppanlp.corpus.PPAText at 0x1400862a0>,
#  <ppanlp.corpus.PPAText at 0x1400861e0>,
#  <ppanlp.corpus.PPAText at 0x140086150>,
#  <ppanlp.corpus.PPAText at 0x140086450>,
#  <ppanlp.corpus.PPAText at 0x140086390>,
#  <ppanlp.corpus.PPAText at 0x140086300>,
#  <ppanlp.corpus.PPAText at 0x140086600>,
#  <ppanlp.corpus.PPAText at 0x140086540>,
#  <ppanlp.corpus.PPAText at 0x1400864b0>,
#  <ppanlp.corpus.PPAText at 0x1400867b0>,
#  <ppanlp.corpus.PPAText at 0x1400866f0>,
#  <ppanlp.corpus.PPAText at 0x140086660>,
#  <ppanlp.corpus.PPAText at 0x140086960>,
#  <ppanlp.corpus.PPAText at 0x1400868a0>,
#  <ppanlp.corpus.PPAText at 0x140086810>,
#  <ppanlp.corpus.PPAText at 0x140086b10>,
#  <ppanlp.corpus.PPAText at 0x140086a50>,
#  <ppanlp.corpus.PPAText at 0x1400869c0>,
#  <ppanlp.corpus.PPAText at 0x140086cc0>,
#  <ppanlp.corpus.PPAText at 0x140086c00>,
#  <ppanlp.corpus.PPAText at 0x140086b70>,
#  <ppanlp.corpus.PPAText at 0x140086ea0>,
#  <ppanlp.corpus.PPAText at 0x140086de0>,
#  <ppanlp.corpus.PPAText at 0x140086d50>,
#  <ppanlp.corpus.PPAText at 0x140087080>,
#  <ppanlp.corpus.PPAText at 0x140086fc0>,
#  <ppanlp.corpus.PPAText at 0x140086f30>,
#  <ppanlp.corpus.PPAText at 0x140087260>,
#  <ppanlp.corpus.PPAText at 0x1400871a0>,
#  <ppanlp.corpus.PPAText at 0x140087110>,
#  <ppanlp.corpus.PPAText at 0x140087440>,
#  <ppanlp.corpus.PPAText at 0x140087320>,
#  <ppanlp.corpus.PPAText at 0x140087620>,
#  <ppanlp.corpus.PPAText at 0x140087590>,
#  <ppanlp.corpus.PPAText at 0x1400874d0>,
#  <ppanlp.corpus.PPAText at 0x1400877d0>,
#  <ppanlp.corpus.PPAText at 0x140087740>,
#  <ppanlp.corpus.PPAText at 0x140087680>,
#  <ppanlp.corpus.PPAText at 0x140087980>,
#  <ppanlp.corpus.PPAText at 0x1400878f0>,
#  <ppanlp.corpus.PPAText at 0x140087830>,
#  <ppanlp.corpus.PPAText at 0x140087b30>,
#  <ppanlp.corpus.PPAText at 0x140087aa0>,
#  <ppanlp.corpus.PPAText at 0x1400879e0>,
#  <ppanlp.corpus.PPAText at 0x140087ce0>,
#  <ppanlp.corpus.PPAText at 0x140087c50>,
#  <ppanlp.corpus.PPAText at 0x140087b90>,
#  <ppanlp.corpus.PPAText at 0x140087e90>,
#  <ppanlp.corpus.PPAText at 0x140087e00>,
#  <ppanlp.corpus.PPAText at 0x140087d40>,
#  <ppanlp.corpus.PPAText at 0x140087fb0>,
#  <ppanlp.corpus.PPAText at 0x140087ef0>,
#  <ppanlp.corpus.PPAText at 0x1400a4080>,
#  <ppanlp.corpus.PPAText at 0x1400a4230>,
#  <ppanlp.corpus.PPAText at 0x1400a41a0>,
#  <ppanlp.corpus.PPAText at 0x1400a40e0>,
#  <ppanlp.corpus.PPAText at 0x1400a43e0>,
#  <ppanlp.corpus.PPAText at 0x1400a4350>,
#  <ppanlp.corpus.PPAText at 0x1400a4290>,
#  <ppanlp.corpus.PPAText at 0x1400a4590>,
#  <ppanlp.corpus.PPAText at 0x1400a44a0>,
#  <ppanlp.corpus.PPAText at 0x1400a4410>,
#  <ppanlp.corpus.PPAText at 0x1400a46e0>,
#  <ppanlp.corpus.PPAText at 0x1400a45f0>,
#  <ppanlp.corpus.PPAText at 0x1400a48c0>,
#  <ppanlp.corpus.PPAText at 0x1400a4830>,
#  <ppanlp.corpus.PPAText at 0x1400a4770>,
#  <ppanlp.corpus.PPAText at 0x1400a4a70>,
#  <ppanlp.corpus.PPAText at 0x1400a49e0>,
#  <ppanlp.corpus.PPAText at 0x1400a4920>,
#  <ppanlp.corpus.PPAText at 0x1400a4c20>,
#  <ppanlp.corpus.PPAText at 0x1400a4b90>,
#  <ppanlp.corpus.PPAText at 0x1400a4ad0>,
#  <ppanlp.corpus.PPAText at 0x1400a4dd0>,
#  <ppanlp.corpus.PPAText at 0x1400a4d40>,
#  <ppanlp.corpus.PPAText at 0x1400a4c80>,
#  <ppanlp.corpus.PPAText at 0x1400a4f80>,
#  <ppanlp.corpus.PPAText at 0x1400a4ef0>,
#  <ppanlp.corpus.PPAText at 0x1400a4e30>,
#  <ppanlp.corpus.PPAText at 0x1400a5130>,
#  <ppanlp.corpus.PPAText at 0x1400a50a0>,
#  <ppanlp.corpus.PPAText at 0x1400a4fe0>,
#  <ppanlp.corpus.PPAText at 0x1400a52e0>,
#  <ppanlp.corpus.PPAText at 0x1400a5250>,
#  <ppanlp.corpus.PPAText at 0x1400a5190>,
#  <ppanlp.corpus.PPAText at 0x1400a5490>,
#  <ppanlp.corpus.PPAText at 0x1400a5400>,
#  <ppanlp.corpus.PPAText at 0x1400a5340>,
#  <ppanlp.corpus.PPAText at 0x1400a5640>,
#  <ppanlp.corpus.PPAText at 0x1400a55b0>,
#  <ppanlp.corpus.PPAText at 0x1400a54f0>,
#  <ppanlp.corpus.PPAText at 0x1400a5850>,
#  <ppanlp.corpus.PPAText at 0x1400a5760>,
#  <ppanlp.corpus.PPAText at 0x1400a56a0>,
#  <ppanlp.corpus.PPAText at 0x1400a5a60>,
#  <ppanlp.corpus.PPAText at 0x1400a5970>,
#  <ppanlp.corpus.PPAText at 0x1400a58b0>,
#  <ppanlp.corpus.PPAText at 0x1400a5c10>,
#  <ppanlp.corpus.PPAText at 0x1400a5b80>,
#  <ppanlp.corpus.PPAText at 0x1400a5ac0>,
#  <ppanlp.corpus.PPAText at 0x1400a5dc0>,
#  <ppanlp.corpus.PPAText at 0x1400a5d30>,
#  <ppanlp.corpus.PPAText at 0x1400a5c70>,
#  <ppanlp.corpus.PPAText at 0x1400a5f70>,
#  <ppanlp.corpus.PPAText at 0x1400a5ee0>,
#  <ppanlp.corpus.PPAText at 0x1400a5e20>,
#  <ppanlp.corpus.PPAText at 0x1400a6120>,
#  <ppanlp.corpus.PPAText at 0x1400a6090>,
#  <ppanlp.corpus.PPAText at 0x1400a5fd0>,
#  <ppanlp.corpus.PPAText at 0x1400a62a0>,
#  <ppanlp.corpus.PPAText at 0x1400a6210>,
#  <ppanlp.corpus.PPAText at 0x1400a6180>,
#  <ppanlp.corpus.PPAText at 0x1400a6450>,
#  <ppanlp.corpus.PPAText at 0x1400a63c0>,
#  <ppanlp.corpus.PPAText at 0x1400a6300>,
#  <ppanlp.corpus.PPAText at 0x1400a65d0>,
#  <ppanlp.corpus.PPAText at 0x1400a6540>,
#  <ppanlp.corpus.PPAText at 0x1400a64b0>,
#  <ppanlp.corpus.PPAText at 0x1400a6780>,
#  <ppanlp.corpus.PPAText at 0x1400a66f0>,
#  <ppanlp.corpus.PPAText at 0x1400a6630>,
#  <ppanlp.corpus.PPAText at 0x1400a6930>,
#  <ppanlp.corpus.PPAText at 0x1400a68a0>,
#  <ppanlp.corpus.PPAText at 0x1400a67e0>,
#  <ppanlp.corpus.PPAText at 0x1400a6ae0>,
#  <ppanlp.corpus.PPAText at 0x1400a69f0>,
#  <ppanlp.corpus.PPAText at 0x1400a6960>,
#  <ppanlp.corpus.PPAText at 0x1400a6c30>,
#  <ppanlp.corpus.PPAText at 0x1400a6b40>,
#  <ppanlp.corpus.PPAText at 0x1400a6e40>,
#  <ppanlp.corpus.PPAText at 0x1400a6db0>,
#  <ppanlp.corpus.PPAText at 0x1400a6cf0>,
#  <ppanlp.corpus.PPAText at 0x1400a6ff0>,
#  <ppanlp.corpus.PPAText at 0x1400a6f60>,
#  <ppanlp.corpus.PPAText at 0x1400a6ea0>,
#  <ppanlp.corpus.PPAText at 0x1400a71a0>,
#  <ppanlp.corpus.PPAText at 0x1400a70e0>,
#  <ppanlp.corpus.PPAText at 0x1400a7050>,
#  <ppanlp.corpus.PPAText at 0x1400a7320>,
#  <ppanlp.corpus.PPAText at 0x1400a7290>,
#  <ppanlp.corpus.PPAText at 0x1400a7200>,
#  <ppanlp.corpus.PPAText at 0x1400a74d0>,
#  <ppanlp.corpus.PPAText at 0x1400a7440>,
#  <ppanlp.corpus.PPAText at 0x1400a7380>,
#  <ppanlp.corpus.PPAText at 0x1400a7710>,
#  <ppanlp.corpus.PPAText at 0x1400a7650>,
#  <ppanlp.corpus.PPAText at 0x1400a7530>,
#  <ppanlp.corpus.PPAText at 0x1400a78f0>,
#  <ppanlp.corpus.PPAText at 0x1400a7830>,
#  <ppanlp.corpus.PPAText at 0x1400a7770>,
#  <ppanlp.corpus.PPAText at 0x1400a7aa0>,
#  <ppanlp.corpus.PPAText at 0x1400a7a10>,
#  <ppanlp.corpus.PPAText at 0x1400a7950>,
#  <ppanlp.corpus.PPAText at 0x1400a7c20>,
#  <ppanlp.corpus.PPAText at 0x1400a7b60>,
#  <ppanlp.corpus.PPAText at 0x1400a7ad0>,
#  <ppanlp.corpus.PPAText at 0x1400a7da0>,
#  <ppanlp.corpus.PPAText at 0x1400a7ce0>,
#  <ppanlp.corpus.PPAText at 0x1400a7c50>,
#  <ppanlp.corpus.PPAText at 0x1400a7f50>,
#  <ppanlp.corpus.PPAText at 0x1400a7e90>,
#  <ppanlp.corpus.PPAText at 0x1400a7e00>,
#  <ppanlp.corpus.PPAText at 0x1400a7fb0>,
#  <ppanlp.corpus.PPAText at 0x1400c41a0>,
#  <ppanlp.corpus.PPAText at 0x1400c4080>,
#  <ppanlp.corpus.PPAText at 0x1400c43b0>,
#  <ppanlp.corpus.PPAText at 0x1400c4290>,
#  <ppanlp.corpus.PPAText at 0x1400c4200>,
#  <ppanlp.corpus.PPAText at 0x1400c4590>,
#  <ppanlp.corpus.PPAText at 0x1400c4440>,
#  <ppanlp.corpus.PPAText at 0x1400c4770>,
#  <ppanlp.corpus.PPAText at 0x1400c46e0>,
#  <ppanlp.corpus.PPAText at 0x1400c4620>,
#  <ppanlp.corpus.PPAText at 0x1400c4920>,
#  <ppanlp.corpus.PPAText at 0x1400c4890>,
#  <ppanlp.corpus.PPAText at 0x1400c47d0>,
#  <ppanlp.corpus.PPAText at 0x1400c4b30>,
#  <ppanlp.corpus.PPAText at 0x1400c4a40>,
#  <ppanlp.corpus.PPAText at 0x1400c4980>,
#  <ppanlp.corpus.PPAText at 0x1400c4d10>,
#  <ppanlp.corpus.PPAText at 0x1400c4c50>,
#  <ppanlp.corpus.PPAText at 0x1400c4b90>,
#  <ppanlp.corpus.PPAText at 0x1400c4f20>,
#  <ppanlp.corpus.PPAText at 0x1400c4e30>,
#  <ppanlp.corpus.PPAText at 0x1400c4d70>,
#  <ppanlp.corpus.PPAText at 0x1400c50d0>,
#  <ppanlp.corpus.PPAText at 0x1400c4fe0>,
#  <ppanlp.corpus.PPAText at 0x1400c4f50>,
#  <ppanlp.corpus.PPAText at 0x1400c5250>,
#  <ppanlp.corpus.PPAText at 0x1400c5130>,
#  <ppanlp.corpus.PPAText at 0x1400c5460>,
#  <ppanlp.corpus.PPAText at 0x1400c5370>,
#  <ppanlp.corpus.PPAText at 0x1400c52e0>,
#  <ppanlp.corpus.PPAText at 0x1400c55b0>,
#  <ppanlp.corpus.PPAText at 0x1400c54c0>,
#  <ppanlp.corpus.PPAText at 0x1400c57f0>,
#  <ppanlp.corpus.PPAText at 0x1400c5700>,
#  <ppanlp.corpus.PPAText at 0x1400c5640>,
#  <ppanlp.corpus.PPAText at 0x1400c59a0>,
#  <ppanlp.corpus.PPAText at 0x1400c58b0>,
#  <ppanlp.corpus.PPAText at 0x1400c5820>,
#  <ppanlp.corpus.PPAText at 0x1400c5af0>,
#  <ppanlp.corpus.PPAText at 0x1400c5a00>,
#  <ppanlp.corpus.PPAText at 0x1400c5d00>,
#  <ppanlp.corpus.PPAText at 0x1400c5c70>,
#  <ppanlp.corpus.PPAText at 0x1400c5bb0>,
#  <ppanlp.corpus.PPAText at 0x1400c5eb0>,
#  <ppanlp.corpus.PPAText at 0x1400c5e20>,
#  <ppanlp.corpus.PPAText at 0x1400c5d60>,
#  <ppanlp.corpus.PPAText at 0x1400c6090>,
#  <ppanlp.corpus.PPAText at 0x1400c5fd0>,
#  <ppanlp.corpus.PPAText at 0x1400c5f10>,
#  <ppanlp.corpus.PPAText at 0x1400c6270>,
#  <ppanlp.corpus.PPAText at 0x1400c61b0>,
#  <ppanlp.corpus.PPAText at 0x1400c60f0>,
#  <ppanlp.corpus.PPAText at 0x1400c6450>,
#  <ppanlp.corpus.PPAText at 0x1400c6390>,
#  <ppanlp.corpus.PPAText at 0x1400c62d0>,
#  <ppanlp.corpus.PPAText at 0x1400c6630>,
#  <ppanlp.corpus.PPAText at 0x1400c6570>,
#  <ppanlp.corpus.PPAText at 0x1400c64b0>,
#  <ppanlp.corpus.PPAText at 0x1400c67e0>,
#  <ppanlp.corpus.PPAText at 0x1400c6750>,
#  ...]

# %%
text = random.choice(ppa.texts)

# %%
text.pages_df
# Out:
#                         page_num page_num_orig  \
# page_id
# mdp.39015059909286_1           1             1
# mdp.39015059909286_2           2             2
# mdp.39015059909286_3           3             3
# mdp.39015059909286_4           4             4
# mdp.39015059909286_5           5             5
# ...                          ...           ...
# mdp.39015059909286_322       322           322
# mdp.39015059909286_323       323           323
# mdp.39015059909286_324       324           324
# mdp.39015059909286_325       325           325
# mdp.39015059909286_326       326           326
#
#                                                                 page_text  \
# page_id
# mdp.39015059909286_1    \nDECLAMATIONS\nHOW TO SPEAK THEM\nEdited by E...
# mdp.39015059909286_2    \nP\n.\n18370 watt.......!\nARTES\nSCIENTIA\nV...
# mdp.39015059909286_3                                              350 W\n
# mdp.39015059909286_4
# mdp.39015059909286_5                      *\nr\ni\n'.\n;\n;..\no i\nt)i\n
# ...                                                                   ...
# mdp.39015059909286_322
# mdp.39015059909286_323                                                 \n
# mdp.39015059909286_324
# mdp.39015059909286_325      3 9015 05990 9286\n\nUNIVERSITY OF MICHIGAN\n
# mdp.39015059909286_326                                                 \n
#
#                                                            page_text_orig  \
# page_id
# mdp.39015059909286_1    \nDECLAMATIONS\nHOW TO SPEAK THEM\nEdited by E...
# mdp.39015059909286_2    \nP\n.\n18370 watt.......!\nARTES\nSCIENTIA\nV...
# mdp.39015059909286_3                                              350 W\n
# mdp.39015059909286_4
# mdp.39015059909286_5                      *\nr\ni\n'.\n;\n;..\no i\nt)i\n
# ...                                                                   ...
# mdp.39015059909286_322
# mdp.39015059909286_323                                                 \n
# mdp.39015059909286_324
# mdp.39015059909286_325      3 9015 05990 9286\n\nUNIVERSITY OF MICHIGAN\n
# mdp.39015059909286_326                                                 \n
#
#                                                               page_tokens  \
# page_id
# mdp.39015059909286_1    [declamations, how, to, speak, them, edited, b...
# mdp.39015059909286_2    [p, watt, artes, scientia, veritas, of, the, h...
# mdp.39015059909286_3                                                  [w]
# mdp.39015059909286_4                                                   []
# mdp.39015059909286_5                                   [r, i, o, i, t, i]
# ...                                                                   ...
# mdp.39015059909286_322                                                 []
# mdp.39015059909286_323                                                 []
# mdp.39015059909286_324                                                 []
# mdp.39015059909286_325                         [university, of, michigan]
# mdp.39015059909286_326                                                 []
#
#                        page_corrections_headers page_corrections_linebreaks  \
# page_id
# mdp.39015059909286_1                         []                          []
# mdp.39015059909286_2        [[............., ]]                          []
# mdp.39015059909286_3              [[20 %. ?, ]]                          []
# mdp.39015059909286_4                         []                          []
# mdp.39015059909286_5                         []                          []
# ...                                         ...                         ...
# mdp.39015059909286_322                       []                          []
# mdp.39015059909286_323                       []                          []
# mdp.39015059909286_324                       []                          []
# mdp.39015059909286_325                       []                          []
# mdp.39015059909286_326                       []                          []
#
#                        page_corrections_long_s page_corrections_ocr  \
# page_id
# mdp.39015059909286_1                        []                   []
# mdp.39015059909286_2                        []                   []
# mdp.39015059909286_3                        []                   []
# mdp.39015059909286_4                        []                   []
# mdp.39015059909286_5                        []                   []
# ...                                        ...                  ...
# mdp.39015059909286_322                      []                   []
# mdp.39015059909286_323                      []                   []
# mdp.39015059909286_324                      []                   []
# mdp.39015059909286_325                      []                   []
# mdp.39015059909286_326                      []                   []
#
#                        page_corrections_f_s
# page_id
# mdp.39015059909286_1                     []
# mdp.39015059909286_2                     []
# mdp.39015059909286_3                     []
# mdp.39015059909286_4                     []
# mdp.39015059909286_5                     []
# ...                                     ...
# mdp.39015059909286_322                   []
# mdp.39015059909286_323                   []
# mdp.39015059909286_324                   []
# mdp.39015059909286_325                   []
# mdp.39015059909286_326                   []
#
# [326 rows x 10 columns]

# %%
# for t in ppa:
#     t.clean_pages()
#     pass

# %%
def cleanup_mp(work_id):
    t = PPA().get_text(work_id)
    return t.clean_pages()

# %%
work_ids = list(ppa.meta.index)
# work_ids

# %%
# cleanup_mp(random.choice(work_ids))

# %%
def clean_pages(self, work_ids=None, num_proc=None):
    work_ids = list(self.meta.index) if work_ids == None else work_ids
    num_proc=(mp.cpu_count()//2)-1 if not num_proc else num_proc
    num_proc=num_proc if num_proc>0 else 1
    pool = mp.Pool(num_proc)

    random.shuffle(work_ids)
    objs = work_ids
    res = list(tqdm(pool.imap_unordered(cleanup_mp,objs), total=len(objs), position=0, desc=f'Cleaning PPA pages (script from Wouter Haverals) [{num_proc}x]'))
    return res

# %%
clean_pages(PPA())
# Out:
# Cleaning PPA pages (script from Wouter Haverals) [7x]:   3%|▎         | 186/6939 [00:29<19:35,  5.74it/s]
