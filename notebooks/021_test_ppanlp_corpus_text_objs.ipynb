# %%
import sys;sys.path.append('..')
from ppanlp.corpus import *
from ppanlp.cleanup import *
import multiprocessing as mp
mp.set_start_method('fork')

# %%
ppa = PPA('~/ppa_data/corpus', clean=False)

# %%
ppa.texts
# Out:
# Iteration over texts in PPA: 100%|██████████| 6939/6939 [00:00<00:00, 409458.01it/s]
# ...
#  ...]

# %%
text = random.choice(ppa.texts)

# %%
text.pages_df
# Out:
#                     page_num page_num_orig          page_text
# page_id
# wu.89099903049_1           1             1                 \n
# wu.89099903049_2           2             2          \n\n]\n\n
# wu.89099903049_3           3             3
# wu.89099903049_4           4             4
# wu.89099903049_5           5             5
# ...                      ...           ...                ...
# wu.89099903049_266       272           266
# wu.89099903049_267       273           267
# wu.89099903049_268       274           268  \nB89099903049A\n
# wu.89099903049_269       275           269                 \n
# wu.89099903049_270       276           270                 \n
#
# [276 rows x 3 columns]

# %%
for t in ppa:
    for p in t:
        pass
# Out:
# Iteration over texts in PPA: 100%|██████████| 6939/6939 [00:29<00:00, 235.82it/s]
