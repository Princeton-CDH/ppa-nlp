# %% [markdown]
# # Topic modeling

# %%
# !pip install -U orjson sqlitedict tomotopy nltk pyLDAvis altair ipywidgets

# %%
import os
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
from tqdm.auto import tqdm
import orjson
import zlib
import tomotopy as tp
from sqlitedict import SqliteDict
import topicwizard
import random
import pyLDAvis
from collections import Counter
import nltk
from nltk.corpus import stopwords as stops
import numpy as np

# %%
# corpus
path_corpus=os.path.expanduser('~/ppa_data/solrcorpus2')
path_metadata = os.path.join(path_corpus, 'metadata.csv')
path_pages = os.path.join(path_corpus, 'corpus.sqlitedict')

# %%
# Read metadata
# df_metadata = pd.read_csv(path_metadata).fillna('').set_index('work_id')
# df_metadata

# %%
def encode_cache(x): return sqlite3.Binary(zlib.compress(orjson.dumps(x)))
def decode_cache(x): return orjson.loads(zlib.decompress(bytes(x)))
def get_pages_db():
    return SqliteDict(path_pages, flag='r', tablename='texts', encode=encode_cache, decode=decode_cache)
def get_meta_db():
    return SqliteDict(path_pages, flag='r', tablename='metadata', encode=encode_cache, decode=decode_cache)

# %%
CLUSTER_KEY='cluster_id_s'

def iter_pages(lim=None,min_num_words=None,max_pages_per_doc=None,max_pages_per_cluster=None, collections={}):
    num=0
    clustercounts=Counter()
    breaknow=False
    with get_pages_db() as db, get_meta_db() as mdb:
        for work_id in tqdm(list(db.keys()),desc='Iterating works',position=0):
            if breaknow: break

            meta = mdb[work_id]
            if collections and not set(meta['collections']) & set(collections):
                continue
            pages = db[work_id]
            cluster = meta.get(CLUSTER_KEY,work_id)

            if min_num_words:
                pages = [d for d in pages if len(d['page_tokens'])>=min_num_words]

            if max_pages_per_doc:
                random.shuffle(pages)
                pages=pages[:max_pages_per_doc]

            pbar2=tqdm(pages,desc='Iterating pages',position=1,disable=True)
            for page in pbar2:
                if not max_pages_per_cluster or clustercounts[cluster]<max_pages_per_cluster:
                    yield dict(
                        work_cluster = cluster,
                        **page
                    )
                    clustercounts[cluster]+=1
                    num+=1
                    if lim and num>=lim:
                        breaknow=True
                        break
            pbar2.close()

def iter_corpus(lim=None,max_pages_per_doc=25,**kwargs):
    yield from iter_pages(lim=lim,min_num_words=25,collections={'Literary','Linguistic'},max_pages_per_doc=max_pages_per_doc,**kwargs)

def iter_sample(lim=None):
    yield from iter_corpus(lim=lim, max_pages_per_cluster=25, max_pages_per_doc=25)

# next(iter_pages(collections=['Linguistic']))
# for x in iter_pages(max_pages_per_cluster=1): pass
# for i,x in enumerate(iter_corpus()): pass
# i
# next(iter_corpus())

# %%
stopwords = set(stops.words('english'))
def clean_toks(toks):
    return [tok for tok in toks if len(tok)>3 and tok not in stopwords]

# %%
def topic_model(ntopic=50, force=False, niter=100):
    fn=f'data.tomotopy.model.ntopic={ntopic}.bin'
    fnindex=fn+'.index.json'
    if force or not os.path.exists(fn) or not os.path.exists(fnindex):
        mdl = tp.LDAModel(k=50)
        docd={}
        for page in iter_sample():
            toks = clean_toks(page['page_tokens'])
            docd[page['page_id']] = mdl.add_doc(toks)

        def getdesc():
            return f'Training model (ndocs={len(docd)}, log-likelihood = {mdl.ll_per_word:.4})'
        pbar=tqdm(list(range(0, niter, 10)),desc=getdesc(),position=0)
        for i in pbar:
            pbar.set_description(getdesc())
            mdl.train(10)
        mdl.save(fn)
        with open(fnindex,'wb') as of:
            of.write(orjson.dumps(docd))
    else:
        print(f'Loading model: {fn}')
        mdl = tp.LDAModel.load(fn)
        print(f'Loading model index: {fnindex}')
        with open(fnindex,'rb') as f:
            docd=orjson.loads(f.read())

    mdl.summary()
    return mdl,docd

# %%
mdl,docd = topic_model(force=False)
# Out:
# Loading model: data.tomotopy.model.ntopic=50.bin
# Loading model index: data.tomotopy.model.ntopic=50.bin.index.json
# <Basic Info>
# | LDAModel (current version: 0.12.5)
# | 102993 docs, 14788350 words
# | Total Vocabs: 1218037, Used Vocabs: 1218037
# | Entropy of words: 10.02966
# | Entropy of term-weighted words: 10.02966
# | Removed Vocabs: <NA>
# |
# <Training Info>
# | Iterations: 100, Burn-in steps: 0
# | Optimization Interval: 10
# | Log-likelihood per word: -10.38120
# |
# <Initial Parameters>
# | tw: TermWeight.ONE
# | min_cf: 0 (minimum collection frequency of words)
# | min_df: 0 (minimum document frequency of words)
# | rm_top: 0 (the number of top words to be removed)
# | k: 50 (the number of topics between 1 ~ 32767)
# | alpha: [0.1] (hyperparameter of Dirichlet distribution for document-topic, given as a single `float` in case of symmetric prior and as a list with length `k` of `float` in case of asymmetric prior.)
# | eta: 0.01 (hyperparameter of Dirichlet distribution for topic-word)
# | seed: 3097823306 (random seed)
# | trained in version 0.12.5
# |
# <Parameters>
# | alpha (Dirichlet prior on the per-document topic distributions)
# |  [0.26227176 0.11506399 0.03285861 0.07679065 0.00923859 0.02513527
# |   0.08124888 0.02287436 0.05314855 0.00749319 0.08974517 0.05729252
# |   0.03945235 0.01331402 0.00816904 0.02727689 0.02713322 0.1241152
# |   0.01238072 0.05581073 0.1470048  0.12732139 0.05423285 0.02434245
# |   0.0613206  0.09788665 0.13075775 0.09247503 0.08456635 0.03035676
# |   0.05751467 0.00943628 0.014477   0.01619946 0.00542959 0.03527955
# |   0.00735967 0.006345   0.00703526 0.01561359 0.06057166 0.03019896
# |   0.01486184 0.21018605 0.04944267 0.07348954 0.02910629 0.00843257
# |   0.0265325  0.12212832]
# | eta (Dirichlet prior on the per-topic word distribution)
# |  0.01
# |
# <Topics>
# | #0 (1351831) : would must words upon sense
# | #1 (473429) : like little white tree black
# | #2 (167407) : part wind rhymes pret tear
# | #3 (336767) : thou thee shall lord come
# | #4 (56336) : page read comma colon line
# | #5 (202466) : quod quam sunt quid esse
# | #6 (403130) : king years year first great
# | #7 (170959) : used part water body called
# | #8 (211943) : church religion christ holy christian
# | #9 (55001) : cast beat weighed bring pref
# | #10 (539195) : fame upon much would every
# | #11 (308767) : english latin french language greek
# | #12 (277599) : verse line syllables lines syllable
# | #13 (146659) : dans vous pour plus nous
# | #14 (60644) : τους bible περί προς note
# | #15 (179636) : play plays shakespeare stage spenser
# | #16 (171636) : thing make place state person
# | #17 (570719) : great poetry style genius much
# | #18 (86851) : ablative hine genitive dative note
# | #19 (332358) : edition first book text century
# | #20 (777040) : love like light heart earth
# | #21 (518860) : said time came would could
# | #22 (262907) : john london thomas william printed
# | #23 (188881) : verb tense present verbs past
# | #24 (233188) : river water town land ship
# | #25 (536925) : work english study school language
# | #26 (805697) : poetry life poet work even
# | #27 (379937) : blood arms death thus battle
# | #28 (383709) : words write sentences sentence following
# | #29 (222938) : sound vowel sounds vowels long
# | #30 (291395) : words word form pronunciation spelling
# | #31 (141825) : nicht sich eine auch dass
# | #32 (79107) : rife life write fill foul
# | #33 (97092) : tion ness ment sion less
# | #34 (85898) : speling hwen hwig reform dhat
# | #35 (138885) : plural woman female wife male
# | #36 (64119) : spanish para como madrid lope
# | #37 (58379) : goth prep agus ασur fear
# | #38 (59802) : tile fully ally kara fron
# | #39 (155667) : ther alle also whan chaucer
# | #40 (508077) : noun verb used sentence nouns
# | #41 (147975) : number three four first times
# | #42 (67924) : note paris france french dame
# | #43 (904026) : would good much well know
# | #44 (304379) : university york english book college
# | #45 (320671) : voice music tone vocal sound
# | #46 (161964) : thle fame tile cafe thie
# | #47 (60844) : part name fide water spring
# | #48 (93553) : gives able webster senate international
# | #49 (633353) : would people great country state
# |

# %%
print('Calculating topic_term_dists')
topic_term_dists = np.stack([mdl.get_topic_word_dist(k) for k in range(mdl.k)])


print('Calculating doc_topic_dists')
doc_topic_dists = np.stack([doc.get_topic_dist() for doc in mdl.docs])
doc_topic_dists /= doc_topic_dists.sum(axis=1, keepdims=True)

print('Calculating doc_lengths')
doc_lengths = np.array([len(doc.words) for doc in mdl.docs])


print('Calculating vocab')
vocab = list(mdl.used_vocabs)
term_frequency = mdl.used_vocab_freq

print('preparing data')
prepared_data = pyLDAvis.prepare(
    topic_term_dists, 
    doc_topic_dists, 
    doc_lengths, 
    vocab, 
    term_frequency,
    start_index=0, # tomotopy starts topic ids with 0, pyLDAvis with 1
    sort_topics=False # IMPORTANT: otherwise the topic_ids between pyLDAvis and tomotopy are not matching!
)

print('saving html')
pyLDAvis.save_html(prepared_data, 'ldavis.html')
# Out:
# Calculating topic_term_dists
# Calculating doc_topic_dists
# Calculating doc_lengths
# Calculating vocab
# preparing data
# saving html

# %%
# !open ldavis.html

# %%
doc_topic_dists
# Out:
# 102993

# %%
id2doc={v:k for k,v in docd.items()}
id2doc
index,values = zip(*[(id2doc[i],x) for i,x in enumerate(doc_topic_dists) if i in id2doc])
dftopicdist = pd.DataFrame(values, index=index)
dftopicdist
# Out:
#                               0         1         2         3         4   \
# uc1.$b305400_81         0.349220  0.007596  0.013849  0.000523  0.000063
# uc1.$b305400_160        0.269306  0.000789  0.000225  0.000527  0.000063
# uc1.$b305400_80         0.259611  0.000707  0.000202  0.000472  0.000057
# uc1.$b305400_xviii      0.139942  0.042234  0.000227  0.000530  0.000064
# uc1.$b305400_173        0.484849  0.000817  0.000233  0.000545  0.000066
# ...                          ...       ...       ...       ...       ...
# njp.32101023512898_315  0.021212  0.039762  0.000214  0.000499  0.000060
# njp.32101023512898_201  0.002552  0.001119  0.000320  0.000747  0.000090
# njp.32101023512898_23   0.001931  0.000847  0.000242  0.037387  0.000068
# njp.32101023512898_255  0.001811  0.007701  0.007133  0.014343  0.000064
# njp.32101023512898_367  0.033095  0.000893  0.039078  0.295649  0.000072
#
#                               5         6         7         8         9   ...  \
# uc1.$b305400_81         0.000171  0.000554  0.000156  0.007174  0.000051  ...
# uc1.$b305400_160        0.000172  0.000557  0.000157  0.000365  0.000051  ...
# uc1.$b305400_80         0.000154  0.000499  0.000141  0.000326  0.000046  ...
# uc1.$b305400_xviii      0.000174  0.000561  0.000158  0.000367  0.000052  ...
# uc1.$b305400_173        0.000179  0.000577  0.000162  0.000378  0.000053  ...
# ...                          ...       ...       ...       ...       ...  ...
# njp.32101023512898_315  0.000163  0.000528  0.000149  0.000346  0.000049  ...
# njp.32101023512898_201  0.000245  0.117532  0.000223  0.010246  0.000073  ...
# njp.32101023512898_23   0.000185  0.000598  0.007533  0.000391  0.000055  ...
# njp.32101023512898_255  0.000174  0.014374  0.000158  0.000367  0.000052  ...
# njp.32101023512898_367  0.000195  0.000631  0.000178  0.015942  0.000058  ...
#
#                               40        41        42        43        44  \
# uc1.$b305400_81         0.000413  0.000206  0.000101  0.001432  0.000337
# uc1.$b305400_160        0.000415  0.000207  0.000102  0.001442  0.020917
# uc1.$b305400_80         0.000372  0.000186  0.000091  0.001291  0.012589
# uc1.$b305400_xviii      0.000418  0.000209  0.000103  0.022171  0.027968
# uc1.$b305400_173        0.000430  0.000214  0.000106  0.008596  0.000351
# ...                          ...       ...       ...       ...       ...
# njp.32101023512898_315  0.000394  0.000196  0.000097  0.007869  0.000321
# njp.32101023512898_201  0.020046  0.000294  0.000145  0.060416  0.000481
# njp.32101023512898_23   0.007810  0.000222  0.000109  0.200383  0.000364
# njp.32101023512898_255  0.000418  0.000209  0.000103  0.201741  0.000341
# njp.32101023512898_367  0.000470  0.000234  0.000115  0.257862  0.000384
#
#                               45        46        47        48        49
# uc1.$b305400_81         0.000501  0.000198  0.000057  0.000181  0.048519
# uc1.$b305400_160        0.000504  0.000200  0.000058  0.000182  0.007697
# uc1.$b305400_80         0.049594  0.000179  0.000052  0.000163  0.000750
# uc1.$b305400_xviii      0.028134  0.000201  0.000058  0.000183  0.000843
# uc1.$b305400_173        0.000522  0.000207  0.000060  0.000188  0.000867
# ...                          ...       ...       ...       ...       ...
# njp.32101023512898_315  0.000478  0.000189  0.000055  0.000173  0.013799
# njp.32101023512898_201  0.000715  0.000283  0.000082  0.000258  0.166573
# njp.32101023512898_23   0.000541  0.000214  0.000062  0.051745  0.192371
# njp.32101023512898_255  0.062666  0.000201  0.000058  0.000183  0.049189
# njp.32101023512898_367  0.000571  0.000226  0.000065  0.000206  0.000948
#
# [102216 rows x 50 columns]

# %%
dftopicdist[20].sort_values()
# Out:
# coo.31924106553286_610     0.000096
# umn.31951p00293997r_337    0.000125
# nyp.33433069240756_46      0.000129
# coo.31924057525671_1069    0.000136
# umn.31951p00293997r_230    0.000136
#                              ...
# mdp.39015053481746_288     0.924038
# hvd.hnpb3g_82              0.926045
# uva.x000417034_71          0.926355
# CW0111495029_91            0.945233
# nyp.33433082522859_68      0.949309
# Name: 20, Length: 102216, dtype: float32

# %%
# with get_meta_db() as mdb:
#     dftopicdist['cluster']=[mdb.get(id.split('_')[0],{}).get(CLUSTER_KEY,id.split('_')[0]) for id in tqdm(dftopicdist.index,desc='Gathering metadata')]

# %%
dfmeta = pd.read_csv(path_metadata).set_index('work_id')
dfmeta
# Out:
#                              source_id          group_id_s        source_t  \
# work_id
# mdp.39015050663247  mdp.39015050663247  mdp.39015050663247  ['HathiTrust']
# uc1.$b305400              uc1.$b305400        uc1.$b305400  ['HathiTrust']
# nyp.33433069253601  nyp.33433069253601  nyp.33433069253601  ['HathiTrust']
# nyp.33433082310818  nyp.33433082310818  nyp.33433082310818  ['HathiTrust']
# njp.32101066384684  njp.32101066384684  njp.32101066384684  ['HathiTrust']
# ...                                ...                 ...             ...
# CW0117117042              CW0117117042        CW0117117042        ['Gale']
# uc1.b3385165-p277         uc1.b3385165   uc1.b3385165-p291  ['HathiTrust']
# wu.89090360363          wu.89090360363      wu.89090360363  ['HathiTrust']
# nyp.33433069240749  nyp.33433069240749  nyp.33433069240749  ['HathiTrust']
# njp.32101023512898  njp.32101023512898  njp.32101023512898  ['HathiTrust']
#
#                                                            source_url  \
# work_id
# mdp.39015050663247     https://hdl.handle.net/2027/mdp.39015050663247
# uc1.$b305400                 https://hdl.handle.net/2027/uc1.$b305400
# nyp.33433069253601     https://hdl.handle.net/2027/nyp.33433069253601
# nyp.33433082310818     https://hdl.handle.net/2027/nyp.33433082310818
# njp.32101066384684     https://hdl.handle.net/2027/njp.32101066384684
# ...                                                               ...
# CW0117117042        https://link.gale.com/apps/doc/CW0117117042/EC...
# uc1.b3385165-p277            https://hdl.handle.net/2027/uc1.b3385165
# wu.89090360363             https://hdl.handle.net/2027/wu.89090360363
# nyp.33433069240749     https://hdl.handle.net/2027/nyp.33433069240749
# njp.32101023512898     https://hdl.handle.net/2027/njp.32101023512898
#
#                                                                 title  \
# work_id
# mdp.39015050663247             The imperial encyclopaedic dictionary;
# uc1.$b305400                              Teaching the language-arts;
# nyp.33433069253601            The psychology and pedagogy of reading,
# nyp.33433082310818              A hand-book of the English language :
# njp.32101066384684                  Watson's manual of calisthenics :
# ...                                                               ...
# CW0117117042                      Reflections upon accuracy of style.
# uc1.b3385165-p277   Chaucer's Use of the Octosyllabic Verse in The...
# wu.89090360363                    The institutes of English grammar :
# nyp.33433069240749  The etymologic interpreter, or, An explanatory...
# njp.32101023512898                                      Miscellanies.
#
#                                                              subtitle  \
# work_id
# mdp.39015050663247  a new and exhaustive work of reference to the ...
# uc1.$b305400                            speech, reading, composition,
# nyp.33433069253601  with a review of the history of reading and wr...
# nyp.33433082310818  for the use of students of the universities an...
# njp.32101066384684  a systematic drill-book without apparatus, for...
# ...                                                               ...
# CW0117117042                                   By Mr. John Constable.
# uc1.b3385165-p277                                                 NaN
# wu.89090360363      methodically arranged; with examples for parsi...
# nyp.33433069240749  to which is prefixed an introduction containin...
# njp.32101023512898                                                NaN
#
#                                                            sort_title  \
# work_id
# mdp.39015050663247  imperial encyclopaedic dictionary; a new and e...
# uc1.$b305400        Teaching the language-arts; speech, reading, c...
# nyp.33433069253601  psychology and pedagogy of reading, with a rev...
# nyp.33433082310818  hand-book of the English language : for the us...
# njp.32101066384684  Watson's manual of calisthenics : a systematic...
# ...                                                               ...
# CW0117117042        Reflections upon accuracy of style. By Mr. Joh...
# uc1.b3385165-p277   Chaucer's Use of the Octosyllabic Verse in The...
# wu.89090360363      institutes of English grammar : methodically a...
# nyp.33433069240749  etymologic interpreter, or, An explanatory and...
# njp.32101023512898                                      Miscellanies.
#
#                     pub_date                pub_place  \
# work_id
# mdp.39015050663247    1901.0                   London
# uc1.$b305400          1897.0                 New York
# nyp.33433069253601    1908.0                 New York
# nyp.33433082310818    1852.0                New York
# njp.32101066384684    1889.0                 New York
# ...                      ...                      ...
# CW0117117042          1731.0                  London
# uc1.b3385165-p277     1913.0           Evanston, Ill.
# wu.89090360363        1844.0                 New-York
# nyp.33433069240749    1824.0                   London
# njp.32101023512898    1911.0  London, Chatto & Windus
#
#                                                             publisher  ...  \
# work_id                                                                ...
# mdp.39015050663247                      Dictionary and Cyclopedia Co.  ...
# uc1.$b305400                                  D. Appleton and company  ...
# nyp.33433069253601                                          Macmillan  ...
# nyp.33433082310818                              D. Appleton & Company  ...
# njp.32101066384684                                   E. Steiger & Co.  ...
# ...                                                               ...  ...
# CW0117117042        Henry Lintot, at the Cross-Keys, between the T...  ...
# uc1.b3385165-p277                                    Journal Pub. Co.  ...
# wu.89090360363                           Samuel S. & William Wood ...  ...
# nyp.33433069240749                                          R. Hunter  ...
# njp.32101023512898                                                NaN  ...
#
#                                         collections_exact  \
# work_id
# mdp.39015050663247                       ['Dictionaries']
# uc1.$b305400                               ['Linguistic']
# nyp.33433069253601             ['Linguistic', 'Literary']
# nyp.33433082310818                         ['Linguistic']
# njp.32101066384684                ['Linguistic', 'Music']
# ...                                                   ...
# CW0117117042                   ['Linguistic', 'Literary']
# uc1.b3385165-p277   ['Literary', 'Original Bibliography']
# wu.89090360363                             ['Linguistic']
# nyp.33433069240749           ['Linguistic', 'Word Lists']
# njp.32101023512898                           ['Literary']
#
#                             cluster_id_s item_type order work_type_s  \
# work_id
# mdp.39015050663247    mdp.39015050663247      work     0   full-work
# uc1.$b305400            hinsdaleteaching      work     0   full-work
# nyp.33433069253601        hueypsychology      work     0   full-work
# nyp.33433082310818        lathamhandbook      work     0   full-work
# njp.32101066384684          watsonmanual      work     0   full-work
# ...                                  ...       ...   ...         ...
# CW0117117042        constablereflections      work     0   full-work
# uc1.b3385165-p277      uc1.b3385165-p291      work     0     article
# wu.89090360363           browninstitutes      work     0   full-work
# nyp.33433069240749    nyp.33433069240749      work     0   full-work
# njp.32101023512898    njp.32101023512898      work     0   full-work
#
#                                last_modified            _version_  \
# work_id
# mdp.39015050663247  2023-02-14T19:34:41.987Z  1757836247823286273
# uc1.$b305400        2023-02-14T19:59:29.859Z  1757837808047751168
# nyp.33433069253601  2023-02-14T19:34:44.284Z  1757836250242351105
# nyp.33433082310818  2023-02-14T19:34:41.531Z  1757836247340941312
# njp.32101066384684  2023-02-14T19:59:30.769Z  1757837808944283648
# ...                                      ...                  ...
# CW0117117042        2023-02-14T19:59:27.388Z  1757837805372833795
# uc1.b3385165-p277   2023-02-14T19:59:11.585Z  1757837788847276039
# wu.89090360363      2023-02-14T19:34:41.987Z  1757836247827480578
# nyp.33433069240749  2023-02-14T19:34:40.597Z  1757836246372057094
# njp.32101023512898  2023-02-14T19:59:21.950Z  1757837799710523395
#
#                     first_page_i  \
# work_id
# mdp.39015050663247           NaN
# uc1.$b305400                 NaN
# nyp.33433069253601           NaN
# nyp.33433082310818           NaN
# njp.32101066384684           NaN
# ...                          ...
# CW0117117042                 NaN
# uc1.b3385165-p277          291.0
# wu.89090360363               NaN
# nyp.33433069240749           NaN
# njp.32101023512898           NaN
#
#                                                     book_journal_s notes
# work_id
# mdp.39015050663247                                             NaN   NaN
# uc1.$b305400                                                   NaN   NaN
# nyp.33433069253601                                             NaN   NaN
# nyp.33433082310818                                             NaN   NaN
# njp.32101066384684                                             NaN   NaN
# ...                                                            ...   ...
# CW0117117042                                                   NaN   NaN
# uc1.b3385165-p277   The Journal of English and Germanic philology.   NaN
# wu.89090360363                                                 NaN   NaN
# nyp.33433069240749                                             NaN   NaN
# njp.32101023512898                                             NaN   NaN
#
# [6319 rows x 24 columns]

# %%
dftopicdist['work_id']=[i.split('_')[0] for i in dftopicdist.index]

# %%
with get_meta_db() as mdb:
    dfmeta = pd.DataFrame({'work_id':wid, **mdb[wid]} for wid in tqdm(mdb, total=len(mdb), position=0, desc='Gathering metadata')).set_index('work_id')
    w2c = dict(zip(dfmeta.index, dfmeta[CLUSTER_KEY]))
dfmeta
# Out:
# Gathering metadata:   0%|          | 0/6319 [00:00<?, ?it/s]
# Gathering metadata: 100%|██████████| 6319/6319 [00:02<00:00, 2988.17it/s]
#                              source_id          group_id_s      source_t  \
# work_id
# mdp.39015050663247  mdp.39015050663247  mdp.39015050663247  [HathiTrust]
# uc1.$b305400              uc1.$b305400        uc1.$b305400  [HathiTrust]
# nyp.33433069253601  nyp.33433069253601  nyp.33433069253601  [HathiTrust]
# nyp.33433082310818  nyp.33433082310818  nyp.33433082310818  [HathiTrust]
# njp.32101066384684  njp.32101066384684  njp.32101066384684  [HathiTrust]
# ...                                ...                 ...           ...
# CW0117117042              CW0117117042        CW0117117042        [Gale]
# uc1.b3385165-p277         uc1.b3385165   uc1.b3385165-p291  [HathiTrust]
# wu.89090360363          wu.89090360363      wu.89090360363  [HathiTrust]
# nyp.33433069240749  nyp.33433069240749  nyp.33433069240749  [HathiTrust]
# njp.32101023512898  njp.32101023512898  njp.32101023512898  [HathiTrust]
#
#                                                            source_url  \
# work_id
# mdp.39015050663247     https://hdl.handle.net/2027/mdp.39015050663247
# uc1.$b305400                 https://hdl.handle.net/2027/uc1.$b305400
# nyp.33433069253601     https://hdl.handle.net/2027/nyp.33433069253601
# nyp.33433082310818     https://hdl.handle.net/2027/nyp.33433082310818
# njp.32101066384684     https://hdl.handle.net/2027/njp.32101066384684
# ...                                                               ...
# CW0117117042        https://link.gale.com/apps/doc/CW0117117042/EC...
# uc1.b3385165-p277            https://hdl.handle.net/2027/uc1.b3385165
# wu.89090360363             https://hdl.handle.net/2027/wu.89090360363
# nyp.33433069240749     https://hdl.handle.net/2027/nyp.33433069240749
# njp.32101023512898     https://hdl.handle.net/2027/njp.32101023512898
#
#                                                                 title  \
# work_id
# mdp.39015050663247             The imperial encyclopaedic dictionary;
# uc1.$b305400                              Teaching the language-arts;
# nyp.33433069253601            The psychology and pedagogy of reading,
# nyp.33433082310818              A hand-book of the English language :
# njp.32101066384684                  Watson's manual of calisthenics :
# ...                                                               ...
# CW0117117042                      Reflections upon accuracy of style.
# uc1.b3385165-p277   Chaucer's Use of the Octosyllabic Verse in The...
# wu.89090360363                    The institutes of English grammar :
# nyp.33433069240749  The etymologic interpreter, or, An explanatory...
# njp.32101023512898                                      Miscellanies.
#
#                                                              subtitle  \
# work_id
# mdp.39015050663247  a new and exhaustive work of reference to the ...
# uc1.$b305400                            speech, reading, composition,
# nyp.33433069253601  with a review of the history of reading and wr...
# nyp.33433082310818  for the use of students of the universities an...
# njp.32101066384684  a systematic drill-book without apparatus, for...
# ...                                                               ...
# CW0117117042                                   By Mr. John Constable.
# uc1.b3385165-p277                                                 NaN
# wu.89090360363      methodically arranged; with examples for parsi...
# nyp.33433069240749  to which is prefixed an introduction containin...
# njp.32101023512898                                                NaN
#
#                                                            sort_title  \
# work_id
# mdp.39015050663247  imperial encyclopaedic dictionary; a new and e...
# uc1.$b305400        Teaching the language-arts; speech, reading, c...
# nyp.33433069253601  psychology and pedagogy of reading, with a rev...
# nyp.33433082310818  hand-book of the English language : for the us...
# njp.32101066384684  Watson's manual of calisthenics : a systematic...
# ...                                                               ...
# CW0117117042        Reflections upon accuracy of style. By Mr. Joh...
# uc1.b3385165-p277   Chaucer's Use of the Octosyllabic Verse in The...
# wu.89090360363      institutes of English grammar : methodically a...
# nyp.33433069240749  etymologic interpreter, or, An explanatory and...
# njp.32101023512898                                      Miscellanies.
#
#                     pub_date                pub_place  \
# work_id
# mdp.39015050663247    1901.0                   London
# uc1.$b305400          1897.0                 New York
# nyp.33433069253601    1908.0                 New York
# nyp.33433082310818    1852.0                New York
# njp.32101066384684    1889.0                 New York
# ...                      ...                      ...
# CW0117117042          1731.0                  London
# uc1.b3385165-p277     1913.0           Evanston, Ill.
# wu.89090360363        1844.0                 New-York
# nyp.33433069240749    1824.0                   London
# njp.32101023512898    1911.0  London, Chatto & Windus
#
#                                                             publisher  ...  \
# work_id                                                                ...
# mdp.39015050663247                      Dictionary and Cyclopedia Co.  ...
# uc1.$b305400                                  D. Appleton and company  ...
# nyp.33433069253601                                          Macmillan  ...
# nyp.33433082310818                              D. Appleton & Company  ...
# njp.32101066384684                                   E. Steiger & Co.  ...
# ...                                                               ...  ...
# CW0117117042        Henry Lintot, at the Cross-Keys, between the T...  ...
# uc1.b3385165-p277                                    Journal Pub. Co.  ...
# wu.89090360363                           Samuel S. & William Wood ...  ...
# nyp.33433069240749                                          R. Hunter  ...
# njp.32101023512898                                                NaN  ...
#
#                                     collections_exact          cluster_id_s  \
# work_id
# mdp.39015050663247                     [Dictionaries]    mdp.39015050663247
# uc1.$b305400                             [Linguistic]      hinsdaleteaching
# nyp.33433069253601             [Linguistic, Literary]        hueypsychology
# nyp.33433082310818                       [Linguistic]        lathamhandbook
# njp.32101066384684                [Linguistic, Music]          watsonmanual
# ...                                               ...                   ...
# CW0117117042                   [Linguistic, Literary]  constablereflections
# uc1.b3385165-p277   [Literary, Original Bibliography]     uc1.b3385165-p291
# wu.89090360363                           [Linguistic]       browninstitutes
# nyp.33433069240749           [Linguistic, Word Lists]    nyp.33433069240749
# njp.32101023512898                         [Literary]    njp.32101023512898
#
#                    item_type order work_type_s             last_modified  \
# work_id
# mdp.39015050663247      work     0   full-work  2023-02-14T19:34:41.987Z
# uc1.$b305400            work     0   full-work  2023-02-14T19:59:29.859Z
# nyp.33433069253601      work     0   full-work  2023-02-14T19:34:44.284Z
# nyp.33433082310818      work     0   full-work  2023-02-14T19:34:41.531Z
# njp.32101066384684      work     0   full-work  2023-02-14T19:59:30.769Z
# ...                      ...   ...         ...                       ...
# CW0117117042            work     0   full-work  2023-02-14T19:59:27.388Z
# uc1.b3385165-p277       work     0     article  2023-02-14T19:59:11.585Z
# wu.89090360363          work     0   full-work  2023-02-14T19:34:41.987Z
# nyp.33433069240749      work     0   full-work  2023-02-14T19:34:40.597Z
# njp.32101023512898      work     0   full-work  2023-02-14T19:59:21.950Z
#
#                               _version_  first_page_i  \
# work_id
# mdp.39015050663247  1757836247823286273           NaN
# uc1.$b305400        1757837808047751168           NaN
# nyp.33433069253601  1757836250242351105           NaN
# nyp.33433082310818  1757836247340941312           NaN
# njp.32101066384684  1757837808944283648           NaN
# ...                                 ...           ...
# CW0117117042        1757837805372833795           NaN
# uc1.b3385165-p277   1757837788847276039         291.0
# wu.89090360363      1757836247827480578           NaN
# nyp.33433069240749  1757836246372057094           NaN
# njp.32101023512898  1757837799710523395           NaN
#
#                                                     book_journal_s notes
# work_id
# mdp.39015050663247                                             NaN   NaN
# uc1.$b305400                                                   NaN   NaN
# nyp.33433069253601                                             NaN   NaN
# nyp.33433082310818                                             NaN   NaN
# njp.32101066384684                                             NaN   NaN
# ...                                                            ...   ...
# CW0117117042                                                   NaN   NaN
# uc1.b3385165-p277   The Journal of English and Germanic philology.   NaN
# wu.89090360363                                                 NaN   NaN
# nyp.33433069240749                                             NaN   NaN
# njp.32101023512898                                             NaN   NaN
#
# [6319 rows x 24 columns]

# %%
dftopicdist['cluster']=[w2c.get(work_id,work_id) for work_id in dftopicdist.work_id]

# %%
dfclust_avgs=dftopicdist.groupby('cluster').mean(numeric_only=True)
dfclust_avgs
# Out:
#                            0         1         2         3         4   \
# cluster
# CB0126124028-p3      0.018492  0.000885  0.013435  0.000590  0.000071
# CB0126231877         0.011353  0.040520  0.035319  0.037811  0.000116
# CB0126249691         0.010112  0.009428  0.006746  0.009638  0.022671
# CB0126337761         0.024113  0.002581  0.001283  0.009431  0.032286
# CB0126838693         0.005094  0.001762  0.002520  0.026758  0.028414
# ...                       ...       ...       ...       ...       ...
# yersinphonorhythmic  0.046296  0.010040  0.000432  0.001532  0.000121
# yorkanalytical       0.064169  0.023761  0.039641  0.016537  0.016362
# yorkenglish          0.022620  0.008517  0.000355  0.007808  0.000100
# youngcollege         0.096136  0.095279  0.006126  0.007702  0.000073
# zumptgrammar         0.142537  0.005442  0.012975  0.001632  0.000043
#
#                            5         6         7         8         9   ...  \
# cluster                                                                ...
# CB0126124028-p3      0.000193  0.000625  0.000176  0.000409  0.000058  ...
# CB0126231877         0.002272  0.006542  0.001811  0.015494  0.001110  ...
# CB0126249691         0.005801  0.002915  0.008222  0.012889  0.031659  ...
# CB0126337761         0.037933  0.001826  0.000872  0.008105  0.005230  ...
# CB0126838693         0.068809  0.004211  0.000495  0.000701  0.163985  ...
# ...                       ...       ...       ...       ...       ...  ...
# yersinphonorhythmic  0.001880  0.007609  0.000301  0.002478  0.000099  ...
# yorkanalytical       0.000457  0.008976  0.004080  0.015089  0.000538  ...
# yorkenglish          0.001156  0.008689  0.000590  0.014803  0.039288  ...
# youngcollege         0.000752  0.023608  0.001750  0.019049  0.000060  ...
# zumptgrammar         0.300111  0.001431  0.002193  0.000250  0.000035  ...
#
#                            40        41        42        43        44  \
# cluster
# CB0126124028-p3      0.000466  0.000232  0.000114  0.102654  0.004774
# CB0126231877         0.002229  0.008328  0.002795  0.019714  0.003436
# CB0126249691         0.028240  0.000727  0.003472  0.061632  0.003849
# CB0126337761         0.026695  0.001347  0.005636  0.039556  0.000977
# CB0126838693         0.002957  0.000398  0.011413  0.008653  0.002306
# ...                       ...       ...       ...       ...       ...
# yersinphonorhythmic  0.002240  0.000397  0.027339  0.016820  0.012532
# yorkanalytical       0.350743  0.002293  0.000080  0.023983  0.001933
# yorkenglish          0.296956  0.009961  0.001873  0.019665  0.008292
# youngcollege         0.001034  0.008100  0.000118  0.093273  0.020196
# zumptgrammar         0.152778  0.002069  0.000223  0.010722  0.000232
#
#                            45        46        47        48        49
# cluster
# CB0126124028-p3      0.000565  0.132014  0.000065  0.000204  0.103053
# CB0126231877         0.004333  0.123366  0.017365  0.004178  0.004442
# CB0126249691         0.002088  0.232079  0.000090  0.000654  0.019427
# CB0126337761         0.003000  0.243978  0.000733  0.010518  0.013538
# CB0126838693         0.001241  0.101204  0.073727  0.000350  0.002234
# ...                       ...       ...       ...       ...       ...
# yersinphonorhythmic  0.030618  0.003481  0.000111  0.000677  0.005686
# yorkanalytical       0.015916  0.001829  0.000045  0.000143  0.014340
# yorkenglish          0.006931  0.005802  0.000091  0.002354  0.007607
# youngcollege         0.014910  0.000231  0.000067  0.006272  0.151447
# zumptgrammar         0.002036  0.000137  0.001445  0.001080  0.009210
#
# [4543 rows x 50 columns]

# %%
dfclust_meta = dfmeta.drop_duplicates(CLUSTER_KEY).set_index(CLUSTER_KEY)
dfclust_meta
# Out:
#                                   source_id               group_id_s  \
# cluster_id_s
# mdp.39015050663247       mdp.39015050663247       mdp.39015050663247
# hinsdaleteaching               uc1.$b305400             uc1.$b305400
# hueypsychology           nyp.33433069253601       nyp.33433069253601
# lathamhandbook           nyp.33433082310818       nyp.33433082310818
# watsonmanual             njp.32101066384684       njp.32101066384684
# ...                                     ...                      ...
# nyp.33433000182992-p253  nyp.33433000182992  nyp.33433000182992-p253
# CW0112455905                   CW0112455905             CW0112455905
# uc1.b3385165-p291              uc1.b3385165        uc1.b3385165-p291
# nyp.33433069240749       nyp.33433069240749       nyp.33433069240749
# njp.32101023512898       njp.32101023512898       njp.32101023512898
#
#                              source_t  \
# cluster_id_s
# mdp.39015050663247       [HathiTrust]
# hinsdaleteaching         [HathiTrust]
# hueypsychology           [HathiTrust]
# lathamhandbook           [HathiTrust]
# watsonmanual             [HathiTrust]
# ...                               ...
# nyp.33433000182992-p253  [HathiTrust]
# CW0112455905                   [Gale]
# uc1.b3385165-p291        [HathiTrust]
# nyp.33433069240749       [HathiTrust]
# njp.32101023512898       [HathiTrust]
#
#                                                                 source_url  \
# cluster_id_s
# mdp.39015050663247          https://hdl.handle.net/2027/mdp.39015050663247
# hinsdaleteaching                  https://hdl.handle.net/2027/uc1.$b305400
# hueypsychology              https://hdl.handle.net/2027/nyp.33433069253601
# lathamhandbook              https://hdl.handle.net/2027/nyp.33433082310818
# watsonmanual                https://hdl.handle.net/2027/njp.32101066384684
# ...                                                                    ...
# nyp.33433000182992-p253     https://hdl.handle.net/2027/nyp.33433000182992
# CW0112455905             https://link.gale.com/apps/doc/CW0112455905/EC...
# uc1.b3385165-p291                 https://hdl.handle.net/2027/uc1.b3385165
# nyp.33433069240749          https://hdl.handle.net/2027/nyp.33433069240749
# njp.32101023512898          https://hdl.handle.net/2027/njp.32101023512898
#
#                                                                      title  \
# cluster_id_s
# mdp.39015050663247                  The imperial encyclopaedic dictionary;
# hinsdaleteaching                               Teaching the language-arts;
# hueypsychology                     The psychology and pedagogy of reading,
# lathamhandbook                       A hand-book of the English language :
# watsonmanual                             Watson's manual of calisthenics :
# ...                                                                    ...
# nyp.33433000182992-p253                             The Theory of Language
# CW0112455905                                      Reliques of Irish poetry
# uc1.b3385165-p291        Chaucer's Use of the Octosyllabic Verse in The...
# nyp.33433069240749       The etymologic interpreter, or, An explanatory...
# njp.32101023512898                                           Miscellanies.
#
#                                                                   subtitle  \
# cluster_id_s
# mdp.39015050663247       a new and exhaustive work of reference to the ...
# hinsdaleteaching                             speech, reading, composition,
# hueypsychology           with a review of the history of reading and wr...
# lathamhandbook           for the use of students of the universities an...
# watsonmanual             a systematic drill-book without apparatus, for...
# ...                                                                    ...
# nyp.33433000182992-p253                                                NaN
# CW0112455905             consisting of heroic poems, odes, elegies, and...
# uc1.b3385165-p291                                                      NaN
# nyp.33433069240749       to which is prefixed an introduction containin...
# njp.32101023512898                                                     NaN
#
#                                                                 sort_title  \
# cluster_id_s
# mdp.39015050663247       imperial encyclopaedic dictionary; a new and e...
# hinsdaleteaching         Teaching the language-arts; speech, reading, c...
# hueypsychology           psychology and pedagogy of reading, with a rev...
# lathamhandbook           hand-book of the English language : for the us...
# watsonmanual             Watson's manual of calisthenics : a systematic...
# ...                                                                    ...
# nyp.33433000182992-p253                                 Theory of Language
# CW0112455905             Reliques of Irish poetry consisting of heroic ...
# uc1.b3385165-p291        Chaucer's Use of the Octosyllabic Verse in The...
# nyp.33433069240749       etymologic interpreter, or, An explanatory and...
# njp.32101023512898                                           Miscellanies.
#
#                          pub_date                pub_place  \
# cluster_id_s
# mdp.39015050663247         1901.0                   London
# hinsdaleteaching           1897.0                 New York
# hueypsychology             1908.0                 New York
# lathamhandbook             1852.0                New York
# watsonmanual               1889.0                 New York
# ...                           ...                      ...
# nyp.33433000182992-p253    1783.0                   London
# CW0112455905               1789.0                [Dublin]
# uc1.b3385165-p291          1913.0           Evanston, Ill.
# nyp.33433069240749         1824.0                   London
# njp.32101023512898         1911.0  London, Chatto & Windus
#
#                                                                  publisher  \
# cluster_id_s
# mdp.39015050663247                           Dictionary and Cyclopedia Co.
# hinsdaleteaching                                   D. Appleton and company
# hueypsychology                                                   Macmillan
# lathamhandbook                                       D. Appleton & Company
# watsonmanual                                              E. Steiger & Co.
# ...                                                                    ...
# nyp.33433000182992-p253  W. Strahan, and T. Cadell, and W. Creech at Ed...
# CW0112455905             George Bonham, printer, South Great George's-S...
# uc1.b3385165-p291                                         Journal Pub. Co.
# nyp.33433069240749                                               R. Hunter
# njp.32101023512898                                                     NaN
#
#                          ...                                    collections  \
# cluster_id_s             ...
# mdp.39015050663247       ...                                 [Dictionaries]
# hinsdaleteaching         ...                                   [Linguistic]
# hueypsychology           ...                         [Linguistic, Literary]
# lathamhandbook           ...                                   [Linguistic]
# watsonmanual             ...                            [Linguistic, Music]
# ...                      ...                                            ...
# nyp.33433000182992-p253  ...  [Linguistic, Literary, Original Bibliography]
# CW0112455905             ...                                     [Literary]
# uc1.b3385165-p291        ...              [Literary, Original Bibliography]
# nyp.33433069240749       ...                       [Linguistic, Word Lists]
# njp.32101023512898       ...                                     [Literary]
#
#                                                      collections_exact  \
# cluster_id_s
# mdp.39015050663247                                      [Dictionaries]
# hinsdaleteaching                                          [Linguistic]
# hueypsychology                                  [Linguistic, Literary]
# lathamhandbook                                            [Linguistic]
# watsonmanual                                       [Linguistic, Music]
# ...                                                                ...
# nyp.33433000182992-p253  [Linguistic, Literary, Original Bibliography]
# CW0112455905                                                [Literary]
# uc1.b3385165-p291                    [Literary, Original Bibliography]
# nyp.33433069240749                            [Linguistic, Word Lists]
# njp.32101023512898                                          [Literary]
#
#                         item_type order work_type_s             last_modified  \
# cluster_id_s
# mdp.39015050663247           work     0   full-work  2023-02-14T19:34:41.987Z
# hinsdaleteaching             work     0   full-work  2023-02-14T19:59:29.859Z
# hueypsychology               work     0   full-work  2023-02-14T19:34:44.284Z
# lathamhandbook               work     0   full-work  2023-02-14T19:34:41.531Z
# watsonmanual                 work     0   full-work  2023-02-14T19:59:30.769Z
# ...                           ...   ...         ...                       ...
# nyp.33433000182992-p253      work     0     excerpt  2023-02-14T19:59:30.769Z
# CW0112455905                 work     0   full-work  2023-02-14T19:59:27.388Z
# uc1.b3385165-p291            work     0     article  2023-02-14T19:59:11.585Z
# nyp.33433069240749           work     0   full-work  2023-02-14T19:34:40.597Z
# njp.32101023512898           work     0   full-work  2023-02-14T19:59:21.950Z
#
#                                    _version_ first_page_i  \
# cluster_id_s
# mdp.39015050663247       1757836247823286273          NaN
# hinsdaleteaching         1757837808047751168          NaN
# hueypsychology           1757836250242351105          NaN
# lathamhandbook           1757836247340941312          NaN
# watsonmanual             1757837808944283648          NaN
# ...                                      ...          ...
# nyp.33433000182992-p253  1757837808917020672        253.0
# CW0112455905             1757837805377028096          NaN
# uc1.b3385165-p291        1757837788847276039        291.0
# nyp.33433069240749       1757836246372057094          NaN
# njp.32101023512898       1757837799710523395          NaN
#
#                                                             book_journal_s  \
# cluster_id_s
# mdp.39015050663247                                                     NaN
# hinsdaleteaching                                                       NaN
# hueypsychology                                                         NaN
# lathamhandbook                                                         NaN
# watsonmanual                                                           NaN
# ...                                                                    ...
# nyp.33433000182992-p253  Dissertations moral and critical. On memory an...
# CW0112455905                                                           NaN
# uc1.b3385165-p291           The Journal of English and Germanic philology.
# nyp.33433069240749                                                     NaN
# njp.32101023512898                                                     NaN
#
#                          notes
# cluster_id_s
# mdp.39015050663247         NaN
# hinsdaleteaching           NaN
# hueypsychology             NaN
# lathamhandbook             NaN
# watsonmanual               NaN
# ...                        ...
# nyp.33433000182992-p253    NaN
# CW0112455905               NaN
# uc1.b3385165-p291          NaN
# nyp.33433069240749         NaN
# njp.32101023512898         NaN
#
# [4279 rows x 23 columns]

# %%
dfclust = dfclust_meta.join(dfclust_avgs)
dfclust
# Out:
#                                   source_id               group_id_s  \
# cluster_id_s
# mdp.39015050663247       mdp.39015050663247       mdp.39015050663247
# hinsdaleteaching               uc1.$b305400             uc1.$b305400
# hueypsychology           nyp.33433069253601       nyp.33433069253601
# lathamhandbook           nyp.33433082310818       nyp.33433082310818
# watsonmanual             njp.32101066384684       njp.32101066384684
# ...                                     ...                      ...
# nyp.33433000182992-p253  nyp.33433000182992  nyp.33433000182992-p253
# CW0112455905                   CW0112455905             CW0112455905
# uc1.b3385165-p291              uc1.b3385165        uc1.b3385165-p291
# nyp.33433069240749       nyp.33433069240749       nyp.33433069240749
# njp.32101023512898       njp.32101023512898       njp.32101023512898
#
#                              source_t  \
# cluster_id_s
# mdp.39015050663247       [HathiTrust]
# hinsdaleteaching         [HathiTrust]
# hueypsychology           [HathiTrust]
# lathamhandbook           [HathiTrust]
# watsonmanual             [HathiTrust]
# ...                               ...
# nyp.33433000182992-p253  [HathiTrust]
# CW0112455905                   [Gale]
# uc1.b3385165-p291        [HathiTrust]
# nyp.33433069240749       [HathiTrust]
# njp.32101023512898       [HathiTrust]
#
#                                                                 source_url  \
# cluster_id_s
# mdp.39015050663247          https://hdl.handle.net/2027/mdp.39015050663247
# hinsdaleteaching                  https://hdl.handle.net/2027/uc1.$b305400
# hueypsychology              https://hdl.handle.net/2027/nyp.33433069253601
# lathamhandbook              https://hdl.handle.net/2027/nyp.33433082310818
# watsonmanual                https://hdl.handle.net/2027/njp.32101066384684
# ...                                                                    ...
# nyp.33433000182992-p253     https://hdl.handle.net/2027/nyp.33433000182992
# CW0112455905             https://link.gale.com/apps/doc/CW0112455905/EC...
# uc1.b3385165-p291                 https://hdl.handle.net/2027/uc1.b3385165
# nyp.33433069240749          https://hdl.handle.net/2027/nyp.33433069240749
# njp.32101023512898          https://hdl.handle.net/2027/njp.32101023512898
#
#                                                                      title  \
# cluster_id_s
# mdp.39015050663247                  The imperial encyclopaedic dictionary;
# hinsdaleteaching                               Teaching the language-arts;
# hueypsychology                     The psychology and pedagogy of reading,
# lathamhandbook                       A hand-book of the English language :
# watsonmanual                             Watson's manual of calisthenics :
# ...                                                                    ...
# nyp.33433000182992-p253                             The Theory of Language
# CW0112455905                                      Reliques of Irish poetry
# uc1.b3385165-p291        Chaucer's Use of the Octosyllabic Verse in The...
# nyp.33433069240749       The etymologic interpreter, or, An explanatory...
# njp.32101023512898                                           Miscellanies.
#
#                                                                   subtitle  \
# cluster_id_s
# mdp.39015050663247       a new and exhaustive work of reference to the ...
# hinsdaleteaching                             speech, reading, composition,
# hueypsychology           with a review of the history of reading and wr...
# lathamhandbook           for the use of students of the universities an...
# watsonmanual             a systematic drill-book without apparatus, for...
# ...                                                                    ...
# nyp.33433000182992-p253                                                NaN
# CW0112455905             consisting of heroic poems, odes, elegies, and...
# uc1.b3385165-p291                                                      NaN
# nyp.33433069240749       to which is prefixed an introduction containin...
# njp.32101023512898                                                     NaN
#
#                                                                 sort_title  \
# cluster_id_s
# mdp.39015050663247       imperial encyclopaedic dictionary; a new and e...
# hinsdaleteaching         Teaching the language-arts; speech, reading, c...
# hueypsychology           psychology and pedagogy of reading, with a rev...
# lathamhandbook           hand-book of the English language : for the us...
# watsonmanual             Watson's manual of calisthenics : a systematic...
# ...                                                                    ...
# nyp.33433000182992-p253                                 Theory of Language
# CW0112455905             Reliques of Irish poetry consisting of heroic ...
# uc1.b3385165-p291        Chaucer's Use of the Octosyllabic Verse in The...
# nyp.33433069240749       etymologic interpreter, or, An explanatory and...
# njp.32101023512898                                           Miscellanies.
#
#                          pub_date                pub_place  \
# cluster_id_s
# mdp.39015050663247         1901.0                   London
# hinsdaleteaching           1897.0                 New York
# hueypsychology             1908.0                 New York
# lathamhandbook             1852.0                New York
# watsonmanual               1889.0                 New York
# ...                           ...                      ...
# nyp.33433000182992-p253    1783.0                   London
# CW0112455905               1789.0                [Dublin]
# uc1.b3385165-p291          1913.0           Evanston, Ill.
# nyp.33433069240749         1824.0                   London
# njp.32101023512898         1911.0  London, Chatto & Windus
#
#                                                                  publisher  \
# cluster_id_s
# mdp.39015050663247                           Dictionary and Cyclopedia Co.
# hinsdaleteaching                                   D. Appleton and company
# hueypsychology                                                   Macmillan
# lathamhandbook                                       D. Appleton & Company
# watsonmanual                                              E. Steiger & Co.
# ...                                                                    ...
# nyp.33433000182992-p253  W. Strahan, and T. Cadell, and W. Creech at Ed...
# CW0112455905             George Bonham, printer, South Great George's-S...
# uc1.b3385165-p291                                         Journal Pub. Co.
# nyp.33433069240749                                               R. Hunter
# njp.32101023512898                                                     NaN
#
#                          ...        40        41        42        43  \
# cluster_id_s             ...
# mdp.39015050663247       ...       NaN       NaN       NaN       NaN
# hinsdaleteaching         ...  0.007254  0.000220  0.000108  0.030993
# hueypsychology           ...  0.010151  0.134479  0.001018  0.009889
# lathamhandbook           ...  0.106128  0.004819  0.000144  0.006720
# watsonmanual             ...  0.000650  0.134907  0.000159  0.006243
# ...                      ...       ...       ...       ...       ...
# nyp.33433000182992-p253  ...  0.146349  0.000221  0.000109  0.036430
# CW0112455905             ...  0.003518  0.002402  0.000236  0.065492
# uc1.b3385165-p291        ...  0.000514  0.000256  0.000126  0.069701
# nyp.33433069240749       ...  0.068494  0.003683  0.001640  0.044043
# njp.32101023512898       ...  0.004855  0.001881  0.001491  0.139070
#
#                                44        45        46        47        48  \
# cluster_id_s
# mdp.39015050663247            NaN       NaN       NaN       NaN       NaN
# hinsdaleteaching         0.021053  0.022735  0.000212  0.000061  0.000193
# hueypsychology           0.041776  0.071535  0.002181  0.000091  0.000285
# lathamhandbook           0.008992  0.014753  0.001088  0.000082  0.000708
# watsonmanual             0.001274  0.469280  0.006567  0.000090  0.000285
# ...                           ...       ...       ...       ...       ...
# nyp.33433000182992-p253  0.000361  0.099478  0.000213  0.000062  0.000194
# CW0112455905             0.000785  0.005924  0.006926  0.023677  0.006458
# uc1.b3385165-p291        0.000420  0.000624  0.000247  0.000072  0.000225
# nyp.33433069240749       0.000835  0.004449  0.000277  0.000455  0.001710
# njp.32101023512898       0.000643  0.024053  0.001017  0.000062  0.006599
#
#                                49
# cluster_id_s
# mdp.39015050663247            NaN
# hinsdaleteaching         0.009542
# hueypsychology           0.008565
# lathamhandbook           0.006486
# watsonmanual             0.020100
# ...                           ...
# nyp.33433000182992-p253  0.007487
# CW0112455905             0.019104
# uc1.b3385165-p291        0.001037
# nyp.33433069240749       0.036810
# njp.32101023512898       0.052953
#
# [4279 rows x 73 columns]

# %%
# !pip install wordcloud
mdl.get_topic_words?
# Out:
# Signature: mdl.get_topic_words(self, topic_id, top_n=10)
# Docstring:
# Return the `top_n` words and its probability in the topic `topic_id`.
# The return type is a `list` of (word:`str`, probability:`float`).
#
# Parameters
# ----------
# topic_id : int
#     an integer in range [0, `k`), indicating the topic
# Type:      builtin_function_or_method

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

wc = WordCloud(background_color='white', width=400, height=600)
wordcloud = wc.generate_from_frequencies(dict(mdl.get_topic_words(0, top_n=100)))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
# Out:
# /Users/ryanheuser/.pyenv/versions/3.10.7/lib/python3.10/site-packages/wordcloud/wordcloud.py:106: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   self.colormap = plt.cm.get_cmap(colormap)
# (-0.5, 399.5, 599.5, -0.5)

# %%
dfmeta.iloc[0]
# Out:
# source_id                                           mdp.39015050663247
# group_id_s                                          mdp.39015050663247
# source_t                                                  [HathiTrust]
# source_url              https://hdl.handle.net/2027/mdp.39015050663247
# title                           The imperial encyclopaedic dictionary;
# subtitle             a new and exhaustive work of reference to the ...
# sort_title           imperial encyclopaedic dictionary; a new and e...
# pub_date                                                        1901.0
# pub_place                                                       London
# publisher                                Dictionary and Cyclopedia Co.
# enumcron                                                           v.2
# author                                       Hunter, Robert, 1823-1897
# author_exact                                 Hunter, Robert, 1823-1897
# collections                                             [Dictionaries]
# collections_exact                                       [Dictionaries]
# cluster_id_s                                        mdp.39015050663247
# item_type                                                         work
# order                                                                0
# work_type_s                                                  full-work
# last_modified                                 2023-02-14T19:34:41.987Z
# _version_                                          1757836247823286273
# first_page_i                                                       NaN
# book_journal_s                                                     NaN
# notes                                                              NaN
# Name: mdp.39015050663247, dtype: object

# %%
import altair as alt
from ipywidgets import interactive, interact, interact_manual, HBox

tnums=list(range(mdl.k))
topicwords_d = {tnum:', '.join([i for i,j in mdl.get_topic_words(tnum)]) for tnum in tnums}
topicnames = [f'{tnum}: {topicwords_d[tnum]}' for tnum in tnums]

def get_wordcloud(tnum):
    wc = WordCloud(background_color='white', width=1200, height=200)
    wordcloud = wc.generate_from_frequencies(dict(mdl.get_topic_words(tnum, top_n=100)))
    return wordcloud

@interact(tname=topicnames)
def plot_topic(tname):
    tnum=int(tname.split(':')[0])
    collections={'Linguistic','Literary'}
    figdf=dfclust.reset_index()[[CLUSTER_KEY,'title','author','pub_date','publisher','pub_place','source_url', 'collections', tnum]]
    figdf['collections']=[[x for x in c if x in collections] for c in figdf.collections]
    figdf['collections'] = figdf['collections'].apply(lambda x: 'Linguistic' if 'Linguistic' in set(x) else (x[0] if x else x))
    figdf=figdf[figdf.collections.apply(bool)]
    figdf.columns = ['cluster', 'title', 'author', 'date', 'publisher', 'pubplace', 'source', 'genre', 'topic']
    figdf = figdf[1700<=figdf.date]

    topicwords = topicwords_d.get(tnum)
    wordcloud=get_wordcloud(tnum)
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")

    
    fig = alt.Chart(figdf).mark_circle(size=60).encode(
        x = alt.X('date', scale=alt.Scale(domain=[1700, 1920])),
        y='topic',
        color='genre',
        tooltip=figdf.columns.tolist()
    ).interactive(
    ).properties(
        width=800,
        height=400,
    # ).facet(
    #     facet='genre:N',
    #     columns=2,
    # ).resolve_scale(
    #     y='independent'
    ).properties(
        title = f'Topic {tnum}: {topicwords}'
    )
    return fig
# Out:
# interactive(children=(Dropdown(description='tname', options=('0: would, must, words, upon, sense, first, witho…

# %%
from string import punctuation

def get_cluster_name(clustid):
    meta = dict(dfclust_meta.loc[clustid])
    return f'{meta["title"].strip(punctuation)[:50]} ({str(meta["pub_date"])[:4]}) [{meta["source_url"]}]'

# %%
get_cluster_name('mdp.39015050663247')
# Out:
# 'The imperial encyclopaedic dictionary (1901) [https://hdl.handle.net/2027/mdp.39015050663247]'

# %%
wordcloud=get_wordcloud(0)
plt.figure()
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.savefig('test.png')

# %%
# !open test.png

# %%
def save_wordclouds(odir='wordclouds'):
    my_dpi=75
    os.makedirs(odir, exist_ok=True)
    for tnum in tqdm(list(range(mdl.k)), desc='Saving wordclouds'):
        wordcloud=get_wordcloud(tnum)
        plt.box(False)
        plt.figure(figsize=(600/my_dpi, 200/my_dpi), dpi=my_dpi)
        plt.imshow(wordcloud, interpolation='bilinear')
        plt.axis("off")
        plt.savefig(f'{odir}/fig.wordcloud.tnum={tnum}.png')
        break

# %%
save_wordclouds()
# Out:
# Saving wordclouds:   0%|          | 0/50 [00:00<?, ?it/s]
# Saving wordclouds:   0%|          | 0/50 [00:00<?, ?it/s]

# %%
def get_topic_info_df():
    tld=[]
    for tnum in tqdm(list(range(mdl.k)), desc='Gathering info on topics'):
        td={
            'Topic':tnum,
            'Topic Name':'',
            'Top Words':', '.join([i for i,j in mdl.get_topic_words(tnum, top_n=50)]),
            'Top Documents':'* '+('\n* '.join(get_cluster_name(c) for c in dfclust.sort_values(tnum,ascending=False).index[:5]))
        }
        tld.append(td)
    tdf=pd.DataFrame(tld).set_index('Topic')
    return tdf

# %%
tdf=get_topic_info_df()
# Out:
# Gathering info on topics:   0%|          | 0/50 [00:00<?, ?it/s]
# Gathering info on topics: 100%|██████████| 50/50 [00:01<00:00, 27.06it/s]

# %%
tdf
# Out:
#       Topic Name                                          Top Words  \
# Topic
# 0                 would, must, words, upon, sense, first, withou...
# 1                 like, little, white, tree, black, head, made, ...
# 2                 part, wind, rhymes, pret, tear, wood, tree, wo...
# 3                 thou, thee, shall, lord, come, love, hath, unt...
# 4                 page, read, comma, colon, line, period, semico...
# 5                 quod, quam, sunt, quid, esse, atque, tibi, mih...
# 6                 king, years, year, first, great, england, time...
# 7                 used, part, water, body, called, kind, made, s...
# 8                 church, religion, christ, holy, christian, div...
# 9                 cast, beat, weighed, bring, pref, brought, fou...
# 10                fame, upon, much, would, every, great, many, w...
# 11                english, latin, french, language, greek, saxon...
# 12                verse, line, syllables, lines, syllable, rhyth...
# 13                dans, vous, pour, plus, nous, mais, tout, bien...
# 14                τους, bible, περί, προς, note, teut, είναι, κα...
# 15                play, plays, shakespeare, stage, spenser, come...
# 16                thing, make, place, state, person, another, pa...
# 17                great, poetry, style, genius, much, works, poe...
# 18                ablative, hine, genitive, dative, note, godes,...
# 19                edition, first, book, text, century, also, tra...
# 20                love, like, light, heart, earth, still, shall,...
# 21                said, time, came, would, could, come, little, ...
# 22                john, london, thomas, william, printed, henry,...
# 23                verb, tense, present, verbs, past, shall, love...
# 24                river, water, town, land, ship, place, great, ...
# 25                work, english, study, school, language, book, ...
# 26                poetry, life, poet, work, even, poem, poems, l...
# 27                blood, arms, death, thus, battle, gods, great,...
# 28                words, write, sentences, sentence, following, ...
# 29                sound, vowel, sounds, vowels, long, consonant,...
# 30                words, word, form, pronunciation, spelling, sy...
# 31                nicht, sich, eine, auch, dass, nach, aber, dur...
# 32                rife, life, write, fill, foul, wife, every, fe...
# 33                tion, ness, ment, sion, less, tive, late, less...
# 34                speling, hwen, hwig, reform, dhat, veri, fonet...
# 35                plural, woman, female, wife, male, singular, l...
# 36                spanish, para, como, madrid, lope, juan, este,...
# 37                goth, prep, agus, ασur, fear, mere, nsed, oaly...
# 38                tile, fully, ally, kara, fron, plin, aristoph,...
# 39                ther, alle, also, whan, chaucer, haue, hire, s...
# 40                noun, verb, used, sentence, nouns, word, subje...
# 41                number, three, four, first, times, group, five...
# 42                note, paris, france, french, dame, saint, horn...
# 43                would, good, much, well, know, must, never, li...
# 44                university, york, english, book, college, amer...
# 45                voice, music, tone, vocal, sound, speech, pitc...
# 46                thle, fame, tile, cafe, thie, ther, thing, tlh...
# 47                part, name, fide, water, spring, town, ibid, p...
# 48                gives, able, webster, senate, international, s...
# 49                would, people, great, country, state, governme...
#
#                                            Top Documents
# Topic
# 0      * The science of rhetoric: an introduction to ...
# 1      * Correlated lessons in language and occupatio...
# 2      * Tiw (1862) [https://hdl.handle.net/2027/uc1....
# 3      * Poetical works (1898) [https://hdl.handle.ne...
# 4      * Indo-Iranian phonology with special referenc...
# 5      * Julian of Toledo 'De vitiis et figuris (1922...
# 6      * The history of England in rhyme (1880) [http...
# 7      * Lexicon technicum (1736) [https://link.gale....
# 8      * THE PREFACE (1753) [https://link.gale.com/ap...
# 9      * Translations from modern Chinese (1916) [htt...
# 10     * A PREFATORY ESSAY ON ELEGY (1769) [https://l...
# 11     * On the origin, development, peculiarities an...
# 12     * On Ancient Greek Rhythm and Metre (1873) [ht...
# 13     * A primer of French verse for upper forms (18...
# 14     * The rhetoric of Aristotle  (1836) [https://h...
# 15     * The arte of English poesie (1869) [https://h...
# 16     * The analyzer and expositor  (1847) [https://...
# 17     * Essays moral and literary (1779) [https://hd...
# 18     * The Authorship of the Old English Bede: A St...
# 19     * The introduction of classical metres into It...
# 20     * Key to practical English prosody and versifi...
# 21     * Dictation exercises to accompany Atwood's la...
# 22     * Books of the time of the restoration, being ...
# 23     * The accidence; or, First rudiments of the La...
# 24     * The Treasury of knowledge and library of ref...
# 25     * The study of rhetoric in the college course ...
# 26     * Coventry Patmore's Literary Criticism (1923)...
# 27     * The works of the English poets (1779) [https...
# 28     * Manual of suggestions for teachers using the...
# 29     * A practical tabular summary of French pronun...
# 30     * The Old French Diphthong EI (EY) and Middle ...
# 31     * Dissertations  (1862) [https://hdl.handle.ne...
# 32     * The Rambler No CXXI. TUESDAY, MAY 14, 1751 (...
# 33     * A plain, rational essay on English grammar (...
# 34     * English dictations for home work (1916) [htt...
# 35     * Ballads in the Cumberland dialect (1828) [ht...
# 36     * A phonetic Spanish reader  (1920) [https://h...
# 37     * A galic and English dictionary (1780) [https...
# 38     * Hermann's elements of the doctrine of metres...
# 39     * The metrical history of Sir William Wallace,...
# 40     * English parsing (1834) [https://hdl.handle.n...
# 41     * The Structure of Simple Rhythm Forms (1903) ...
# 42     * Lydgate's Troy book. A.D. 1412-20 (1906) [ht...
# 43     * Poetical works (1898) [https://hdl.handle.ne...
# 44     * A classified catalogue of educational works ...
# 45     * The vocal organ-- its mechanism (explaining ...
# 46     * A grammatical system of the English language...
# 47     * The circles of Gomer or, an essay towards an...
# 48     * Ten thousand words: how to pronounce them  (...
# 49     * The Library of oratory, ancient and modern  ...
