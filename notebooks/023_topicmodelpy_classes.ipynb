# %%
import sys;sys.path.append('..')
from ppanlp.corpus import PPA
from ppanlp.imports import *
# import multiprocessing as mp
# mp.set_start_method('fork')

# %%
ppa = PPA('~/ppa_data/corpus2')

# %%
tm = ppa.topic_model(ntopic=50,frac_text=1,frac=.05,force=True,max_per_cluster=25, clean=True)

# %%
# tm.prepare_docs()
tm.model()
# Out:
# Iteration over texts in PPA:   9%|▉         | 612/6939 [00:52<17:37,  5.98it/s]

# %%
tm.mdl

# %%
tm.doc_topic_dists_df
# Out:
#                                                                         0  \
# cluster             work_id             page_id
# sheridancompleteSV  CB0126082904        CB0126082904_24          0.000233
#                                         CB0126082904_36          0.000254
#                                         CB0126082904_42          0.000246
#                                         CB0126082904_51          0.092909
#                                         CB0126082904_54          0.000259
# ...                                                                   ...
# yale.39002088447587 yale.39002088447587 yale.39002088447587_338  0.000360
#                                         yale.39002088447587_373  0.009956
#                                         yale.39002088447587_409  0.000869
#                                         yale.39002088447587_411  0.009862
#                                         yale.39002088447587_437  0.000594
#
# ...

# %%
tm.meta
# Out:
#                                source_id           group_id_s      source_t  \
# work_id
# CB0126082904                CB0126082904         CB0126082904        [Gale]
# CB0126086107                CB0126086107         CB0126086107        [Gale]
# CB0126228345                CB0126228345         CB0126228345        [Gale]
# CB0126231877                CB0126231877         CB0126231877        [Gale]
# CB0126246787                CB0126246787         CB0126246787        [Gale]
# ...                                  ...                  ...           ...
# yale.39002004932761  yale.39002004932761  yale.39002004932761  [HathiTrust]
# yale.39002005422606  yale.39002005422606  yale.39002005422606  [HathiTrust]
# yale.39002005422614  yale.39002005422614  yale.39002005422614  [HathiTrust]
# yale.39002032008188  yale.39002032008188  yale.39002032008188  [HathiTrust]
# yale.39002088447587  yale.39002088447587  yale.39002088447587  [HathiTrust]
#
# ...
