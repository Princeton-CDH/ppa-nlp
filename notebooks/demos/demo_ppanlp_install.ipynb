# %% [markdown]
# # Demo of PPANLP

# %%
# install ppanlp package
# !pip uninstall ppanlp -y
# !pip install -qU git+https://github.com/Princeton-CDH/ppa-nlp@jsonl
# Out:
# Found existing installation: ppanlp 0.2.2
# Uninstalling ppanlp-0.2.2:
#   Successfully uninstalled ppanlp-0.2.2
#   WARNING: The script ppanlp is installed in '/home/rh6841/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %% [markdown]
# ## Corpus and text objects from ppanlp
#
# ### Corpus

# %%
# import corpus class
from ppanlp import PPA

# instantiate it, pointing to a path for the corpus
# (in which metadata.json and pages.jsonl.gz live)
ppa = PPA('~/ppa_data/solrcorpus14')

# check out the metadata as a dataframe
ppa.meta
# Out:
# booting PPACorpus at /home/rh6841/ppa_data/solrcorpus14 @ 2023-12-10 19:09:50,167
# ￨ iterating over texts in PPA @ 2023-12-10 19:09:50,167
# ￨ ￨ reading metadata @ 2023-12-10 19:09:50,168
# ￨ ￨ ⎿ 0.03 seconds @ 2023-12-10 19:09:50,200
# ￨ ⎿ 0.04 seconds @ 2023-12-10 19:09:50,211
# ⎿ 0.06 seconds @ 2023-12-10 19:09:50,226
#                                                       author  \
# work_id
# CB0126082904                     Sheridan, Thomas, 1719-1788
# CB0126086107
# CB0126124028-p3
# CB0126228345
# CB0126231877                      Pope, Alexander, 1688-1744
# ...                                                      ...
# yale.39002004932761  Dubos, abbé (Jean-Baptiste), 1670-1742
# yale.39002005422606  Dubos, abbé (Jean-Baptiste), 1670-1742
# yale.39002005422614  Dubos, abbé (Jean-Baptiste), 1670-1742
# yale.39002032008188         Gray, George Buchanan, 1865-1922
# yale.39002088447587                    Clarke, George Somers
#
# ...

# %% [markdown]
# ### Installing ppanlp corpus
#
# Consists of three steps:
# * Indexing
# * Preprocessing
# * Database creation

# %%
# install into the {root folder we gave to PPA()}/data
ppa.install(num_proc=16)
# Out:
# installing corpus: indexing, preprocessing, saving to sqlite @ 2023-12-10 19:09:50,240
# ￨ indexing corpus, storing page ids per work @ 2023-12-10 19:09:50,241
# ￨ ￨ iterating pages by corpus jsonl file @ 2023-12-10 19:09:50,241
# ￨ ￨ ￨ iterating: 2160441it [00:08, 255613.09it/s]
# ￨ ￨ ⎿ 8.45 seconds @ 2023-12-10 19:09:58,695
# ￨ ⎿ 8.58 seconds @ 2023-12-10 19:09:58,820
# ￨ preprocessing jsonl files @ 2023-12-10 19:09:58,848
# ￨ ￨ saving jsonl files to /home/rh6841/ppa_data/solrcorpus14/texts_preproc [16x] @ 2023-12-10 19:09:58,917
# ￨ ￨ ￨ preprocessing [16x]: 6,830 texts done; 91 in queue; 0.11 seconds since last: 100%|██████████| 2160441/2160441 [09:39<00:00, 3727.95it/s]
# ￨ ￨ ⎿ 9 minutes and 42.67 seconds @ 2023-12-10 19:19:41,592
# ￨ ⎿ 9 minutes and 42.77 seconds @ 2023-12-10 19:19:41,620
# ￨ generating page database at /home/rh6841/ppa_data/solrcorpus14/data/pages.sqlite @ 2023-12-10 19:19:41,765
# ￨ ￨ saving preprocessed pages to database @ 2023-12-10 19:19:41,766
# ...
