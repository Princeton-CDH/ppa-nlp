# %%
import sys; sys.path.append('../..')
from ppanlp import *

# %%
ppa=PPA('~/ppa_data/solrcorpus14')
ppa.meta
# Out:
# booting PPACorpus at /Users/ryanheuser/ppa_data/solrcorpus14 @ 2023-12-10 15:41:20,244
# ￨ iterating over texts in PPA @ 2023-12-10 15:41:20,245
# ￨ ￨ reading metadata @ 2023-12-10 15:41:20,246
# ￨ ￨ ⎿ 0.06 seconds @ 2023-12-10 15:41:20,310
# ￨ ⎿ 0.11 seconds @ 2023-12-10 15:41:20,358
# ⎿ 0.13 seconds @ 2023-12-10 15:41:20,377
#                                                       author  \
# work_id
# CB0126082904                     Sheridan, Thomas, 1719-1788
# CB0126086107
# CB0126124028-p3
# CB0126228345
# CB0126231877                      Pope, Alexander, 1688-1744
# ...                                                      ...
# yale.39002004932761  Dubos, abbé (Jean-Baptiste), 1670-1742
# yale.39002005422606  Dubos, abbé (Jean-Baptiste), 1670-1742
# yale.39002005422614  Dubos, abbé (Jean-Baptiste), 1670-1742
# yale.39002032008188         Gray, George Buchanan, 1865-1922
# yale.39002088447587                    Clarke, George Somers
#
# ...

# %%
ppa.install(num_proc=1)
# Out:
# installing corpus: indexing, preprocessing, saving to sqlite @ 2023-12-10 15:41:20,417
# ￨ indexing corpus, storing page ids per work @ 2023-12-10 15:41:20,418
# ￨ preprocessing jsonl files @ 2023-12-10 15:41:20,420
# ￨ ￨ saving jsonl files to /Users/ryanheuser/ppa_data/solrcorpus14/texts_preproc [1x] @ 2023-12-10 15:41:20,438
# ￨ ￨ ￨ preprocessing: 100 texts in queue; 26 finished; 2 minutes and 3 seconds since last completion:   1%|          | 25079/2160441 [02:07<3:00:45, 196.88it/s]
# ￨ ￨ ￨ KeyboardInterrupt  @ 2023-12-10 15:43:28,172
# ￨ ￨ KeyboardInterrupt  @ 2023-12-10 15:43:28,187
# ￨ KeyboardInterrupt  @ 2023-12-10 15:43:28,188
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 ppa.install(num_proc=1)
#
# File ~/github/ppa-nlp/ppanlp/corpus.py:324, in PPACorpus.install(self, num_proc, force, clear)
# ...
