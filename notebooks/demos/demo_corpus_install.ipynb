# %%
import sys; sys.path.append('../..')
from ppanlp import *

# %%
ppa=PPA('~/ppa_data/solrcorpus14')
ppa.meta
# Out:
# booting PPACorpus at /Users/ryanheuser/ppa_data/solrcorpus14 @ 2023-12-10 21:42:13,546
# ￨ iterating over texts in PPA @ 2023-12-10 21:42:13,547
# ￨ ￨ reading metadata @ 2023-12-10 21:42:13,549
# ￨ ￨ ⎿ 0.06 seconds @ 2023-12-10 21:42:13,613
# ￨ ⎿ 0.09 seconds @ 2023-12-10 21:42:13,639
# ⎿ 0.09 seconds @ 2023-12-10 21:42:13,642
#                                                       author  \
# work_id
# CB0126082904                     Sheridan, Thomas, 1719-1788
# CB0126086107
# CB0126124028-p3
# CB0126228345
# CB0126231877                      Pope, Alexander, 1688-1744
# ...                                                      ...
# yale.39002004932761  Dubos, abbé (Jean-Baptiste), 1670-1742
# yale.39002005422606  Dubos, abbé (Jean-Baptiste), 1670-1742
# yale.39002005422614  Dubos, abbé (Jean-Baptiste), 1670-1742
# yale.39002032008188         Gray, George Buchanan, 1865-1922
# yale.39002088447587                    Clarke, George Somers
#
# ...

# %%
# Out:
# True

# %%
ppa.install(num_proc=1)
# Out:
# installing corpus: indexing, preprocessing, saving to sqlite @ 2023-12-10 18:01:34,216
# ￨ indexing corpus, storing page ids per work @ 2023-12-10 18:01:34,218
# ￨ preprocessing jsonl files @ 2023-12-10 18:01:34,219
# ￨ ￨ saving jsonl files to /Users/ryanheuser/ppa_data/solrcorpus14/texts_preproc [1x] @ 2023-12-10 18:01:34,239
# ￨ ￨ ￨ preprocessing [1x]: 190 texts done; 1,000 in queue; 0.11 seconds since last:  14%|█▍        | 308266/2160441 [00:55<05:31, 5590.32it/s]
# ￨ ￨ ￨ KeyboardInterrupt  @ 2023-12-10 18:02:29,729
# ￨ ￨ KeyboardInterrupt  @ 2023-12-10 18:02:29,751
# ￨ KeyboardInterrupt  @ 2023-12-10 18:02:29,752
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 ppa.install(num_proc=1)
#
# File ~/github/ppa-nlp/ppanlp/corpus.py:324, in PPACorpus.install(self, num_proc, force, clear)
# ...
